# %% [markdown]
# # Read Damaged Data

# %% [markdown]
# Data interpretation varies with format, necessitating organization into dataframes for machine readability. This step transforms diverse data into a structured, table-like format, facilitating manipulation and analysis. It's crucial for identifying trends and ensuring data quality, thus setting the foundation for subsequent analytical and predictive tasks in a unified, efficient manner.

# %%
import os
os.listdir()
# Out:
# ['googlechrome.dmg',
#  'Visual Studio Code.app',
#  '<Diego Trevino>+country_no_index.csv',
#  'Postman Agent v0.4.63 for macOS (x64).zip',
#  'Assignment 1 Diego CS450 (1).pdf',
#  'Numpy and Pandas review (2).ipynb',
#  'Assignment 4 (1).docx',
#  'Two-link Practice Answer.pdf',
#  '.DS_Store',
#  'Assignment 4.docx',
#  'Numpy and Pandas review.ipynb',
#  'Assignment 1 Diego CS450.pdf',
#  'Module 2 Mini Lab Diego Trevino (1).pdf',
#  '.localized',
#  'Assignment 3.docx',
#  'Wireshark 4.4.9 Arm 64.dmg',
#  'merged_results.csv',
#  'NewGrad_Job_Application_Tracker.csv',
#  '4.14- Project- Genres Endpoint',
#  'Unconfirmed 439322.crdownload',
#  'Class Registration Form.docx',
#  'DiegoTrevino_Quiz32.ipynb',
#  'Assignment 1.docx',
#  'Diego_G_Resume.docx',
#  'classes.js',
#  'Visual Studio Code 2.app',
#  '20250918_GlutenFreeSwissLeopardNomNom-kwWa-IP47CrBjVz3_source.mp4',
#  'DamagedDataRead.ipynb',
#  'NewGrad_Job_Application_Tracker (1).xlsx',
#  'NewGrad_Job_Application_Tracker.xlsx',
#  'classes.zip',
#  'mysql-workbench-community-8.0.43-macos-arm64.dmg',
#  'Numpy and Pandas review (1).ipynb',
#  '4.14- Project- Genres Endpoint.zip',
#  'Postman Agent.app',
#  '.ipynb_checkpoints',
#  'Notion-4.16.2-arm64.dmg',
#  'VSCode-darwin-universal.zip',
#  'Module 2 Mini Lab Diego Trevino.pdf']

# %%
import glob
csvfiles = glob.glob("*.csv")
csvfiles
# Out:
# ['<Diego Trevino>+country_no_index.csv',
#  'merged_results.csv',
#  'NewGrad_Job_Application_Tracker.csv']

# %% [markdown]
# ## 1.1 Read CSV data

# %%
import pandas as pd
file_path = 'us_tourism.csv'

# Read the CSV file
dataframe_csv1 = pd.read_csv(file_path)

# Display the first few rows of the DataFrame
dataframe_csv1.head(5)
# Out:
#       Region          State         Attraction  \
# 0  Northeast       New York  Statue of Liberty
# 1  Northeast  Massachusetts      Freedom Trail
# 2    Midwest       Illinois       Willis Tower
# 3    Midwest       Michigan    The Great Lakes
# 4      South        Florida       Disney World
#
#                               Description   Food Specialty  \
# 0                Iconic symbol of freedom           Bagels
# 1                 Historic 2.5-mile trail     Clam Chowder
# 2  One of the tallest buildings in the US  Deep-Dish Pizza
# 3       Largest group of freshwater lakes          Pasties
# 4            Famous theme park and resort     Key Lime Pie
#
#                             Food Description Best Time to Visit  \
# 0               Boiled and baked dough rings         Year-round
# 1        Creamy soup with clams and potatoes               Fall
# 2  Thick crust pizza with layers of toppings             Summer
# 3     Pastry filled with meat and vegetables             Winter
# 4         Sweet pie made with Key lime juice             Summer
#
#                    Notable Events
# 0      Fourth of July Celebration
# 1                 Boston Marathon
# 2                Taste of Chicago
# 3  Great Lakes Shipwreck Festival
# 4     Disney's Halloween Festival

# %% [markdown]
# ## 1.2 Handle damaged csv data

# %%
file_path2 = 'us_tourism2damage.csv'

# Read the CSV file

df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame
df
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[20], line 5
#       1 file_path2 = 'us_tourism2damage.csv'
#       3 # Read the CSV file
# ----> 5 df = pd.read_csv(file_path)
#       7 # Display the first few rows of the DataFrame
#       8 df
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/parsers/readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/parsers/c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:838, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File parsers.pyx:905, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2061, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 8 fields in line 48, saw 9

# %% [markdown]
# ### Cannot read damage file by pandas
#
# We need to read file line by line.

# %%
import csv

# Replace 'your_file.csv' with the path to your CSV file
file_path = 'us_tourism2damage.csv'

#read line by line, and filter the bad data
a =0
title = []
gooddata = []
baddata= []

# Please watch the tutorial and fill the code
# Your code:

# %%
gooddata
# Out:
# []

# %%
gooddf = pd.DataFrame(gooddata,columns = title)
gooddf
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## 2.1 Read json data

# %%
jsonfiles = glob.glob("*.json")
jsonfiles
# Out:
# ['damaged.json', 'us_tourism.json']

# %%
# Reading the JSON file
df = pd.read_json(jsonfiles[2],lines = True)

# Displaying the DataFrame
df.head(5)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[25], line 2
#       1 # Reading the JSON file
# ----> 2 df = pd.read_json(jsonfiles[2],lines = True)
#       4 # Displaying the DataFrame
#       5 df.head(5)
#
# IndexError: list index out of range

# %% [markdown]
# ## 2.2 Handle damaged json Data

# %%
# Reading the JSON file
dfDamage = pd.read_json(jsonfiles[0],lines = True)

# Displaying the DataFrame
dfDamage.head(5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 2
#       1 # Reading the JSON file
# ----> 2 dfDamage = pd.read_json(jsonfiles[0],lines = True)
#       4 # Displaying the DataFrame
#       5 dfDamage.head(5)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/json/_json.py:815, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     813     return json_reader
#     814 else:
# --> 815     return json_reader.read()
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/json/_json.py:1023, in JsonReader.read(self)
#    1021         data = ensure_str(self.data)
#    1022         data_lines = data.split("\n")
# -> 1023         obj = self._get_object_parser(self._combine_lines(data_lines))
#    1024 else:
#    1025     obj = self._get_object_parser(self.data)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/json/_json.py:1051, in JsonReader._get_object_parser(self, json)
#    1049 obj = None
#    1050 if typ == "frame":
# -> 1051     obj = FrameParser(json, **kwargs).parse()
#    1053 if typ == "series" or obj is None:
#    1054     if not isinstance(dtype, bool):
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/json/_json.py:1187, in Parser.parse(self)
#    1185 @final
#    1186 def parse(self):
# -> 1187     self._parse()
#    1189     if self.obj is None:
#    1190         return None
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/json/_json.py:1403, in FrameParser._parse(self)
#    1399 orient = self.orient
#    1401 if orient == "columns":
#    1402     self.obj = DataFrame(
# -> 1403         ujson_loads(json, precise_float=self.precise_float), dtype=None
#    1404     )
#    1405 elif orient == "split":
#    1406     decoded = {
#    1407         str(k): v
#    1408         for k, v in ujson_loads(json, precise_float=self.precise_float).items()
#    1409     }
#
# ValueError: Expected object or value

# %% [markdown]
# ### 2.2.1 Simple demo

# %%
import json

# Example JSON data as a list of strings (each string is a JSON object)
json_data = [
    '{"name": "Alice", "age": 25, "city": "New York"}',
    '{"name": "Bob", "age": 30, "city": "San Francisco"}',
    '{"name": "Charlie", "age": 35}',
    '{"name": "Bib", "age": , "city": "Seattle"}',
    '{"name": "Bcob", "city": "Beijing"}',
    '{"name": "Bob", "xxxx": 30, "city": "San Francisco"}'
]

# %%
data = []
for json_str in json_data:
    try:
        # Attempt to parse each line as JSON
        json_obj = json.loads(json_str)

        # Handle missing or extra data
        if 'name' not in json_obj:
            json_obj['name'] = None
        if 'age' not in json_obj:
            json_obj['age'] = None
        if 'city' not in json_obj:
            json_obj['city'] = None

        # Append the valid JSON object to the list
        data.append(json_obj)
    
    except json.JSONDecodeError:
        print(f'Invalid Json data')

# data
# Convert the list of dictionaries to a pandas DataFrame (optional)
dfjson= pd.DataFrame(data)

#print
dfjson[['name','age','city']]
# Out:
# Invalid Json data
#       name   age           city
# 0    Alice  25.0       New York
# 1      Bob  30.0  San Francisco
# 2  Charlie  35.0           None
# 3     Bcob   NaN        Beijing
# 4      Bob   NaN  San Francisco

# %% [markdown]
# ### 2.2.3 Handle the damaged json file

# %%
file_path = 'damaged.json'  # Replace with your file path
data = []
title = ['Region', 'State', 'Attraction', 'Description', 
 'Food Specialty', 'Food Description', 'Best Time to Visit', 'Notable Events']

with open(file_path, 'r') as file:
    for line in file:
        try:
            # Parse the JSON string
            json_obj = json.loads(line)

            # Handle missing data by setting a default value
            # Your code

            # Append the processed JSON object to the list
            data.append(json_obj)
        except json.JSONDecodeError:
            print(f'Invalid Json data: {line}')
            

# Convert the list of dictionaries to a pandas DataFrame (optional)
df = pd.DataFrame(data)

# Display the DataFrame
df
# Out:
# Invalid Json data: {"Region":"Southwest","State":"Texas","Attraction":"The Alamo","Description":"Historic mission and fortress","Food Specialty":,"Food Description":"Fusion of Mexican and American cuisines","Best Time to Visit":"Spring","Notable Events":"San Antonio Fiesta"}
#
# Invalid Json data: {"Region":"South","State":"North Carolina","Attraction":"Great Smoky Mountains National Park","Description":,"Food Specialty":"Pulled Pork BBQ","Food Description":"Slow-cooked barbecue pork","Best Time to Visit":"Summer","Notable Events":"Mountain Music Festivals"}
#
# Invalid Json data: {"Region":"West","State":"Nevada","Attraction":"Las Vegas Strip",,"Food Specialty":"Buffet","Food Description":"All-you-can-eat buffets with various cuisines","Best Time to Visit":"Year-round","Notable Events":"Las Vegas New Year's Eve"}
#
# Invalid Json data: {"Region":"West","State":"Colorado","Attraction":"Rocky Mountain National Park",,"Food Specialty":"Rocky Mountain Oysters","Food Description":"Deep-fried bull testicles","Best Time to Visit":"Summer","Notable Events":"Frozen Dead Guy Days"}
#
# Invalid Json data: {"Region":"Northeast","State":"Connecticut","Attraction":,"Description":"The Museum of America and the Sea","Food Specialty":"Lobster Roll","Food Description":"Fresh lobster meat served on a roll","Best Time to Visit":"Summer","Notable Events":"Mystic Outdoor Art Festival"}
#                Region          State                            Attraction  \
# 0           Northeast       New York                     Statue of Liberty
# 1           Northeast  Massachusetts                         Freedom Trail
# 2             Midwest       Illinois                          Willis Tower
# 3             Midwest       Michigan                       The Great Lakes
# 4               South        Florida                          Disney World
# 5               South      Louisiana                        French Quarter
# 6                West     California                    Golden Gate Bridge
# 7                West         Hawaii        Hawaii Volcanoes National Park
# 8           Southwest        Arizona                          Grand Canyon
# 9   Pacific Northwest     Washington                          Space Needle
# 10  Pacific Northwest         Oregon                           Crater Lake
# 11          Northeast   Pennsylvania                          Liberty Bell
# 12          Northeast     New Jersey               Atlantic City Boardwalk
# 13            Midwest           Ohio                           Cedar Point
# 14            Midwest      Wisconsin                       Wisconsin Dells
# 15              South        Georgia            Savannah Historic District
# 16               West         Alaska                  Denali National Park
# 17          Southwest     New Mexico                      Carlsbad Caverns
# 18          Southwest       Oklahoma       Oklahoma City National Memorial
# 19          Northeast        Vermont                 Ben & Jerry's Factory
# 20          Northeast   Rhode Island                          The Breakers
# 21            Midwest        Indiana           Indianapolis Motor Speedway
# 22            Midwest       Missouri                          Gateway Arch
# 23              South       Kentucky            Mammoth Cave National Park
# 24              South      Tennessee                             Graceland
# 25               West           Utah                    Zion National Park
# 26          Southwest         Nevada                            Hoover Dam
# 27          Southwest     New Mexico             White Sands National Park
# 28  Pacific Northwest          Idaho                            Sun Valley
# 29  Pacific Northwest        Montana                 Glacier National Park
# 30          Northeast  New Hampshire                      Mount Washington
# 31            Midwest   North Dakota      Theodore Roosevelt National Park
# 32            Midwest   South Dakota                        Mount Rushmore
# 33              South        Alabama  USS Alabama Battleship Memorial Park
# 34              South    Mississippi      Vicksburg National Military Park
# 35               West         Oregon             Crater Lake National Park
# 36               West     Washington           Mount Rainier National Park
#
#                                           Description  \
# 0                            Iconic symbol of freedom
# 1                             Historic 2.5-mile trail
# 2              One of the tallest buildings in the US
# 3                   Largest group of freshwater lakes
# 4                        Famous theme park and resort
# 5                   Historic New Orleans neighborhood
# 6                            Iconic suspension bridge
# 7                            Home to active volcanoes
# 8                  One of the world's natural wonders
# 9           Futuristic tower with an observation deck
# 10                             Deepest lake in the US
# 11           Historic symbol of American independence
# 12           Famous boardwalk with casinos and hotels
# 13       Amusement park known for its roller coasters
# 14  Popular family vacation area known for its wat...
# 15  Well-preserved historic architecture and cobbl...
# 16               Home to North America's highest peak
# 17       Over 100 caves beneath the Chihuahuan Desert
# 18  Museum and memorial honoring the victims of th...
# 19                      Famous ice cream factory tour
# 20         Famous Newport mansion from the Gilded Age
# 21                         Iconic auto racing circuit
# 22  Iconic monument symbolizing the Westward Expan...
# 23                    The world's longest cave system
# 24             Elvis Presley's former home and museum
# 25                   Scenic canyons and hiking trails
# 26           Engineering marvel on the Colorado River
# 27                     Unique white gypsum sand dunes
# 28      Famous ski resort and outdoor recreation area
# 29    National park known for its glaciers and trails
# 30  The highest peak in the Northeastern United St...
# 31    Park known for its rugged landscape and history
# 32             Iconic sculpture of four US presidents
# 33                           Historic WWII battleship
# 34          Site of the Civil War Battle of Vicksburg
# 35    Famous for its deep blue lake and water clarity
# 36  Iconic volcano and the highest peak in Washington
#
#               Food Specialty  \
# 0                     Bagels
# 1               Clam Chowder
# 2            Deep-Dish Pizza
# 3                    Pasties
# 4               Key Lime Pie
# 5                  Jambalaya
# 6            Sourdough Bread
# 7                       Poke
# 8               Chimichangas
# 9                     Salmon
# 10           Marionberry Pie
# 11        Philly Cheesesteak
# 12          Salt Water Taffy
# 13                  Buckeyes
# 14              Cheese Curds
# 15             Peach Cobbler
# 16                 King Crab
# 17          Green Chile Stew
# 18       Chicken Fried Steak
# 19               Maple Syrup
# 20                Clam Cakes
# 21  Pork Tenderloin Sandwich
# 22       St. Louis-style BBQ
# 23                    Burgoo
# 24               Memphis BBQ
# 25          Funeral Potatoes
# 26           Shrimp Cocktail
# 27      Blue Corn Enchiladas
# 28            Idaho Potatoes
# 29             Huckleberries
# 30        Apple Cider Donuts
# 31             Knoephla Soup
# 32                   Chislic
# 33      Fried Green Tomatoes
# 34                   Catfish
# 35           Marionberry Pie
# 36                    Salmon
#
#                                      Food Description Best Time to Visit  \
# 0                        Boiled and baked dough rings         Year-round
# 1                 Creamy soup with clams and potatoes               Fall
# 2           Thick crust pizza with layers of toppings             Summer
# 3              Pastry filled with meat and vegetables             Winter
# 4                  Sweet pie made with Key lime juice             Summer
# 5                  Rice dish with meat and vegetables             Spring
# 6                 San Francisco's famous crusty bread             Summer
# 7                                      Raw fish salad         Year-round
# 8                                 Deep-fried burritos               Fall
# 9                               Fresh and smoked fish             Summer
# 10                  Pie made with local marionberries             Summer
# 11  Thinly sliced beef and melted cheese in a long...         Year-round
# 12                           Chewy, sweet taffy candy             Summer
# 13  Confections of peanut butter fudge dipped in c...               Fall
# 14                        Fried or fresh cheese curds             Summer
# 15      Sweet cobbler made with fresh Georgia peaches             Spring
# 16                             Alaskan king crab legs             Summer
# 17              Spicy stew with green chiles and pork               Fall
# 18                 Breaded and fried steak with gravy             Spring
# 19         Iconic syrup made from Vermont maple trees             Summer
# 20                  Deep-fried clam and dough mixture             Summer
# 21             Breaded and fried pork cutlet sandwich             Spring
# 22                 Grilled, then sauced barbeque ribs             Summer
# 23           Thick stew made with meat and vegetables               Fall
# 24                          Slow-cooked pork barbeque             Summer
# 25     Casserole made with potatoes, cheese, and soup             Spring
# 26                          Classic seafood appetizer         Year-round
# 27           Enchiladas made with blue corn tortillas             Spring
# 28             Famous potatoes, often baked or mashed             Winter
# 29                 Wild berries used in pies and jams             Summer
# 30                       Donuts made with apple cider               Fall
# 31                           Potato and dumpling soup               Fall
# 32     Cubed meat, typically lamb or beef, deep-fried             Summer
# 33                   Green tomatoes breaded and fried             Summer
# 34                 Cornmeal-breaded and fried catfish             Summer
# 35                  Pie made with local marionberries             Summer
# 36                              Fresh and smoked fish             Summer
#
#                                    Notable Events
# 0                      Fourth of July Celebration
# 1                                 Boston Marathon
# 2                                Taste of Chicago
# 3                  Great Lakes Shipwreck Festival
# 4                     Disney's Halloween Festival
# 5                                      Mardi Gras
# 6                     San Francisco Jazz Festival
# 7                                 Aloha Festivals
# 8                     Grand Canyon Music Festival
# 9             Seattle International Film Festival
# 10                    Oregon Shakespeare Festival
# 11                       Welcome America Festival
# 12                          Atlantic City Airshow
# 13                                Ohio State Fair
# 14                           Wisconsin State Fair
# 15                        Savannah Music Festival
# 16                   Iditarod Trail Sled Dog Race
# 17       Albuquerque International Balloon Fiesta
# 18                            Oklahoma State Fair
# 19                         Vermont Maple Festival
# 20                          Newport Jazz Festival
# 21                               Indianapolis 500
# 22                   St. Louis Bluesweek Festival
# 23                        Kentucky Derby Festival
# 24                                 Memphis in May
# 25                      Utah Shakespeare Festival
# 26              Las Vegas Electric Daisy Carnival
# 27       Albuquerque International Balloon Fiesta
# 28                 Trailing of the Sheep Festival
# 29                   Montana Huckleberry Festival
# 30                         Keene Pumpkin Festival
# 31             United Tribes International Powwow
# 32                       Sturgis Motorcycle Rally
# 33                       National Shrimp Festival
# 34  Mississippi Delta Blues and Heritage Festival
# 35                    Oregon Shakespeare Festival
# 36            Seattle International Film Festival

# %% [markdown]
# ## 3.1 Read Txt data
#
# Examples for **"split"**
# ```python
# text.split(" ")

# %%
h = 'Region: Northeast State: New York'
result_h = h.split(" ")
result_h
# Out:
# ['Region:', 'Northeast', 'State:', 'New', 'York']

# %%
file_path = 'unstructureddata.txt'  # use your file path

# Read and process the file
current_data= []
result= []
with open(file_path,'r') as file:
    for line in file:
        print(line)
        # Please watch the tutorial and fill the code
        # Your code
# Out:
# Year: 1998
#
# Rank: 401
#
# Company: Turner Corp.
#
# Revenue (in millions): 3639.8
#
# Profit (in millions): 5.9
#
#
#
# Year: 1998
#
# Rank: 402
#
# Company: Reebok International
#
# Revenue (in millions): 3637.4
#
# Profit (in millions): 135.1
#
#
#
# Year: 1998
#
# Rank: 403
#
# Company: Morton International
#
# Revenue (in millions): 3636.5
#
# Profit (in millions): 343
#
#
#
# Year: 1998
#
# Rank: 404
#
# Company: Engelhard
#
# Revenue (in millions): 3630.7
#
# Profit (in millions): 47.8
#
#
#
# Year: 1998
#
# Rank: 405
#
# Company: Temple-Inland
#
# Revenue (in millions): 3625.4
#
# Profit (in millions): 50.8
#
#
#
# Year: 1998
#
# Rank: 406
#
# Company: AirTouch Communications
#
# Revenue (in millions): 3594
#
# Profit (in millions): 448
#
#
#
# Year: 1998
#
# Rank: 407
#
# Company: Shaw Industries
#
# Revenue (in millions): 3575.8
#
# Profit (in millions): 29
#
#
#
# Year: 1998
#
# Rank: 408
#
# Company: Echlin
#
# Revenue (in millions): 3568.6
#
# Profit (in millions): -46.9
#
#
#
# Year: 1998
#
# Rank: 409
#
# Company: Thermo Electron
#
# Revenue (in millions): 3558.3
#
# Profit (in millions): 239.3
#
#
#
# Year: 1998
#
# Rank: 410
#
# Company: UnumProvident
#
# Revenue (in millions): 3553.1
#
# Profit (in millions): 247.3
#
#
#
# Year: 1998
#
# Rank: 411
#
# Company: Saks
#
# Revenue (in millions): 3544.7
#
# Profit (in millions): 62.7
#
#
#
# Year: 1998
#
# Rank: 412
#
# Company: McGraw-Hill
#
# Revenue (in millions): 3534.1
#
# Profit (in millions): 290.7
#
#
#
# Year: 1998
#
# Rank: 413
#
# Company: Micron Technology
#
# Revenue (in millions): 3515.5
#
# Profit (in millions): 332.2
#
#
#
# Year: 1998
#
# Rank: 414
#
# Company: Borden Chemical
#
# Revenue (in millions): 3481.6
#
# Profit (in millions): 278
#
#
#
# Year: 1998
#
# Rank: 415
#
# Company: Rykoff-Sexton
#
# Revenue (in millions): 3477.5
#
# Profit (in millions): 16
#
#
#
# Year: 1998
#
# Rank: 416
#
# Company: Goodrich
#
# Revenue (in millions): 3471
#
# Profit (in millions): 178.2
#
#
#
# Year: 1998
#
# Rank: 417
#
# Company: Reliance Group Holdings
#
# Revenue (in millions): 3442.6
#
# Profit (in millions): 229.4
#
#
#
# Year: 1998
#
# Rank: 418
#
# Company: Willamette Industries
#
# Revenue (in millions): 3438.7
#
# Profit (in millions): 73
#
#
#
# Year: 1998
#
# Rank: 419
#
# Company: State St. Corp.
#
# Revenue (in millions): 3428
#
# Profit (in millions): 380
#
#
#
# Year: 1998
#
# Rank: 420
#
# Company: Richfood Holdings
#
# Revenue (in millions): 3411.6
#
# Profit (in millions): 59.5
#
#
#
# Year: 1998
#
# Rank: 421
#
# Company: Maytag
#
# Revenue (in millions): 3407.9
#
# Profit (in millions): 180.3
#
#
#
# Year: 1998
#
# Rank: 422
#
# Company: USF&G
#
# Revenue (in millions): 3403.9
#
# Profit (in millions): 193.9
#
#
#
# Year: 1998
#
# Rank: 423
#
# Company: Allmerica Financial
#
# Revenue (in millions): 3395.6
#
# Profit (in millions): 209.2
#
#
#
# Year: 1998
#
# Rank: 424
#
# Company: Brink's
#
# Revenue (in millions): 3394.4
#
# Profit (in millions): 110.2
#
#
#
# Year: 1998
#
# Rank: 425
#
# Company: Estee Lauder
#
# Revenue (in millions): 3381.6
#
# Profit (in millions): 197.6
#
#
#
# Year: 1998
#
# Rank: 426
#
# Company: Sealed Air
#
# Revenue (in millions): 3358
#
# Profit (in millions): 261
#
#
#
# Year: 1998
#
# Rank: 427
#
# Company: Yellow Roadway
#
# Revenue (in millions): 3348.9
#
# Profit (in millions): 52.4
#
#
#
# Year: 1998
#
# Rank: 428
#
# Company: Cyprus Amax Minerals
#
# Revenue (in millions): 3346
#
# Profit (in millions): 69
#
#
#
# Year: 1998
#
# Rank: 429
#
# Company: Avery Dennison
#
# Revenue (in millions): 3345.7
#
# Profit (in millions): 204.8
#
#
#
# Year: 1998
#
# Rank: 430
#
# Company: New Century Energies
#
# Revenue (in millions): 3342.5
#
# Profit (in millions): 150.9
#
#
#
# Year: 1998
#
# Rank: 431
#
# Company: Graybar Electric
#
# Revenue (in millions): 3338
#
# Profit (in millions): 53
#
#
#
# Year: 1998
#
# Rank: 432
#
# Company: True Value
#
# Revenue (in millions): 3332
#
# Profit (in millions): N.A.
#
#
#
# Year: 1998
#
# Rank: 433
#
# Company: Trans World Airlines
#
# Revenue (in millions): 3328
#
# Profit (in millions): -110.8
#
#
#
# Year: 1998
#
# Rank: 434
#
# Company: Times Mirror
#
# Revenue (in millions): 3318.5
#
# Profit (in millions): 250.3
#
#
#
# Year: 1998
#
# Rank: 435
#
# Company: Florida Progress
#
# Revenue (in millions): 3315.6
#
# Profit (in millions): 54.3
#
#
#
# Year: 1998
#
# Rank: 436
#
# Company: Constellation Energy
#
# Revenue (in millions): 3307.6
#
# Profit (in millions): 282.8
#
#
#
# Year: 1998
#
# Rank: 437
#
# Company: Alltel
#
# Revenue (in millions): 3263.6
#
# Profit (in millions): 507.9
#
#
#
# Year: 1998
#
# Rank: 438
#
# Company: Hormel Foods
#
# Revenue (in millions): 3256.6
#
# Profit (in millions): 109.5
#
#
#
# Year: 1998
#
# Rank: 439
#
# Company: Whitman
#
# Revenue (in millions): 3250.1
#
# Profit (in millions): 4.1
#
#
#
# Year: 1998
#
# Rank: 440
#
# Company: Smurfit-Stone Container
#
# Revenue (in millions): 3238
#
# Profit (in millions): 1
#
#
#
# Year: 1998
#
# Rank: 441
#
# Company: Newell Rubbermaid
#
# Revenue (in millions): 3234.3
#
# Profit (in millions): 290.4
#
#
#
# Year: 1998
#
# Rank: 442
#
# Company: Beverly Enterprises
#
# Revenue (in millions): 3230.3
#
# Profit (in millions): 58.6
#
#
#
# Year: 1998
#
# Rank: 443
#
# Company: BJ's Wholesale Club
#
# Revenue (in millions): 3226.5
#
# Profit (in millions): 68.3
#
#
#
# Year: 1998
#
# Rank: 444
#
# Company: Hannaford Bros.
#
# Revenue (in millions): 3226.4
#
# Profit (in millions): 59.6
#
#
#
# Year: 1998
#
# Rank: 445
#
# Company: AGCO
#
# Revenue (in millions): 3224.4
#
# Profit (in millions): 168.7
#
#
#
# Year: 1998
#
# Rank: 446
#
# Company: Interstate Bakeries
#
# Revenue (in millions): 3212.4
#
# Profit (in millions): 97.2
#
#
#
# Year: 1998
#
# Rank: 447
#
# Company: Corporate Express
#
# Revenue (in millions): 3196.1
#
# Profit (in millions): 42
#
#
#
# Year: 1998
#
# Rank: 448
#
# Company: Ameren
#
# Revenue (in millions): 3195.3
#
# Profit (in millions): 347.2
#
#
#
# Year: 1998
#
# Rank: 449
#
# Company: York International
#
# Revenue (in millions): 3193.7
#
# Profit (in millions): 47.4
#
#
#
# Year: 1998
#
# Rank: 450
#
# Company: Hasbro
#
# Revenue (in millions): 3188.6
#
# Profit (in millions): 135
#
#
#
# Year: 1998
#
# Rank: 451
#
# Company: Comerica
#
# Revenue (in millions): 3175.4
#
# Profit (in millions): 530.5
#
#
#
# Year: 1998
#
# Rank: 452
#
# Company: Darden Restaurants
#
# Revenue (in millions): 3171.8
#
# Profit (in millions): -91
#
#
#
# Year: 1998
#
# Rank: 453
#
# Company: GenAmerica
#
# Revenue (in millions): 3154
#
# Profit (in millions): 96.2
#
#
#
# Year: 1998
#
# Rank: 454
#
# Company: Long Island Lighting
#
# Revenue (in millions): 3147.7
#
# Profit (in millions): 334
#
#
#
# Year: 1998
#
# Rank: 455
#
# Company: 3Com
#
# Revenue (in millions): 3147.1
#
# Profit (in millions): 374
#
#
#
# Year: 1998
#
# Rank: 456
#
# Company: Mercantile Stores
#
# Revenue (in millions): 3143.8
#
# Profit (in millions): 129.7
#
#
#
# Year: 1998
#
# Rank: 457
#
# Company: Knight-Ridder
#
# Revenue (in millions): 3139.1
#
# Profit (in millions): 413
#
#
#
# Year: 1998
#
# Rank: 458
#
# Company: Thrivent Financial for Lutherans
#
# Revenue (in millions): 3129.9
#
# Profit (in millions): 209.8
#
#
#
# Year: 1998
#
# Rank: 459
#
# Company: Interpublic Group
#
# Revenue (in millions): 3125.8
#
# Profit (in millions): 239.1
#
#
#
# Year: 1998
#
# Rank: 460
#
# Company: Omnicom Group
#
# Revenue (in millions): 3124.8
#
# Profit (in millions): 222.4
#
#
#
# Year: 1998
#
# Rank: 461
#
# Company: Joy Global
#
# Revenue (in millions): 3118.2
#
# Profit (in millions): 139.8
#
#
#
# Year: 1998
#
# Rank: 462
#
# Company: Owens & Minor
#
# Revenue (in millions): 3116.8
#
# Profit (in millions): 24.3
#
#
#
# Year: 1998
#
# Rank: 463
#
# Company: Ventas
#
# Revenue (in millions): 3116
#
# Profit (in millions): 130.9
#
#
#
# Year: 1998
#
# Rank: 464
#
# Company: Level 3 Communications
#
# Revenue (in millions): 3096
#
# Profit (in millions): 248
#
#
#
# Year: 1998
#
# Rank: 465
#
# Company: Penn Traffic
#
# Revenue (in millions): 3074.4
#
# Profit (in millions): -54.6
#
#
#
# Year: 1998
#
# Rank: 466
#
# Company: Kohl's
#
# Revenue (in millions): 3060.1
#
# Profit (in millions): 141.3
#
#
#
# Year: 1998
#
# Rank: 467
#
# Company: PPL
#
# Revenue (in millions): 3048.7
#
# Profit (in millions): 296.2
#
#
#
# Year: 1998
#
# Rank: 468
#
# Company: Millennium Chemicals
#
# Revenue (in millions): 3048
#
# Profit (in millions): 185
#
#
#
# Year: 1998
#
# Rank: 469
#
# Company: Progress Energy
#
# Revenue (in millions): 3024.1
#
# Profit (in millions): 388.3
#
#
#
# Year: 1998
#
# Rank: 470
#
# Company: Dean Foods
#
# Revenue (in millions): 3018.4
#
# Profit (in millions): 86.7
#
#
#
# Year: 1998
#
# Rank: 471
#
# Company: HealthSouth
#
# Revenue (in millions): 3017.3
#
# Profit (in millions): 330.6
#
#
#
# Year: 1998
#
# Rank: 472
#
# Company: Westvaco
#
# Revenue (in millions): 3011
#
# Profit (in millions): 162.7
#
#
#
# Year: 1998
#
# Rank: 473
#
# Company: IMC Global
#
# Revenue (in millions): 2988.6
#
# Profit (in millions): 62.9
#
#
#
# Year: 1998
#
# Rank: 474
#
# Company: Phoenix
#
# Revenue (in millions): 2988.3
#
# Profit (in millions): 164.6
#
#
#
# Year: 1998
#
# Rank: 475
#
# Company: Beneficial
#
# Revenue (in millions): 2955.7
#
# Profit (in millions): 253.7
#
#
#
# Year: 1998
#
# Rank: 476
#
# Company: Longs Drug Stores
#
# Revenue (in millions): 2952.9
#
# Profit (in millions): 57.7
#
#
#
# Year: 1998
#
# Rank: 477
#
# Company: EMC
#
# Revenue (in millions): 2937.9
#
# Profit (in millions): 538.5
#
#
#
# Year: 1998
#
# Rank: 478
#
# Company: Alumax
#
# Revenue (in millions): 2930.9
#
# Profit (in millions): 33.7
#
#
#
# Year: 1998
#
# Rank: 479
#
# Company: Golden West Financial
#
# Revenue (in millions): 2913.8
#
# Profit (in millions): 354.1
#
#
#
# Year: 1998
#
# Rank: 480
#
# Company: Airborne
#
# Revenue (in millions): 2912.4
#
# Profit (in millions): 120.1
#
#
#
# Year: 1998
#
# Rank: 481
#
# Company: Leggett & Platt
#
# Revenue (in millions): 2909.2
#
# Profit (in millions): 208.3
#
#
#
# Year: 1998
#
# Rank: 482
#
# Company: Ace Hardware
#
# Revenue (in millions): 2907.3
#
# Profit (in millions): N.A.
#
#
#
# Year: 1998
#
# Rank: 483
#
# Company: Lutheran Brotherhood
#
# Revenue (in millions): 2900.3
#
# Profit (in millions): 231.6
#
#
#
# Year: 1998
#
# Rank: 484
#
# Company: Lyondell Chemical
#
# Revenue (in millions): 2878
#
# Profit (in millions): 286
#
#
#
# Year: 1998
#
# Rank: 485
#
# Company: Fleetwood Enterprises
#
# Revenue (in millions): 2874.4
#
# Profit (in millions): 124.8
#
#
#
# Year: 1998
#
# Rank: 486
#
# Company: USG
#
# Revenue (in millions): 2874
#
# Profit (in millions): 148
#
#
#
# Year: 1998
#
# Rank: 487
#
# Company: New York Times
#
# Revenue (in millions): 2866.4
#
# Profit (in millions): 262.3
#
#
#
# Year: 1998
#
# Rank: 488
#
# Company: Western Atlas
#
# Revenue (in millions): 2859.3
#
# Profit (in millions): -63.1
#
#
#
# Year: 1998
#
# Rank: 489
#
# Company: Sonoco Products
#
# Revenue (in millions): 2847.8
#
# Profit (in millions): 2.6
#
#
#
# Year: 1998
#
# Rank: 490
#
# Company: Reader's Digest Assn.
#
# Revenue (in millions): 2839
#
# Profit (in millions): 133.5
#
#
#
# Year: 1998
#
# Rank: 491
#
# Company: U.S. Office Products
#
# Revenue (in millions): 2835.9
#
# Profit (in millions): 57.3
#
#
#
# Year: 1998
#
# Rank: 492
#
# Company: FirstEnergy
#
# Revenue (in millions): 2821.4
#
# Profit (in millions): 305.8
#
#
#
# Year: 1998
#
# Rank: 493
#
# Company: Comdisco Holding
#
# Revenue (in millions): 2819
#
# Profit (in millions): 131
#
#
#
# Year: 1998
#
# Rank: 494
#
# Company: Becton Dickinson
#
# Revenue (in millions): 2810.5
#
# Profit (in millions): 300.1
#
#
#
# Year: 1998
#
# Rank: 495
#
# Company: Anixter International
#
# Revenue (in millions): 2805.2
#
# Profit (in millions): 45.3
#
#
#
# Year: 1998
#
# Rank: 496
#
# Company: Barnes & Noble
#
# Revenue (in millions): 2796.9
#
# Profit (in millions): 53.2
#
#
#
# Year: 1998
#
# Rank: 497
#
# Company: Pacific Enterprises
#
# Revenue (in millions): 2777
#
# Profit (in millions): 184
#
#
#
# Year: 1998
#
# Rank: 498
#
# Company: Xcel Energy
#
# Revenue (in millions): 2733.7
#
# Profit (in millions): 237.3
#
#
#
# Year: 1998
#
# Rank: 499
#
# Company: Maxxam
#
# Revenue (in millions): 2729.1
#
# Profit (in millions): 65.2
#
#
#
# Year: 1998
#
# Rank: 500
#
# Company: Asarco
#
# Revenue (in millions): 2721
#
# Profit (in millions): 143.4
#
#
#
# Year: 1999
#
# Rank: 1
#
# Company: General Motors
#
# Revenue (in millions): 161315
#
# Profit (in millions): 2956
#
#
#
# Year: 1999
#
# Rank: 2
#
# Company: Ford Motor
#
# Revenue (in millions): 144416
#
# Profit (in millions): 22071
#
#
#
# Year: 1999
#
# Rank: 3
#
# Company: Wal-Mart Stores
#
# Revenue (in millions): 139208
#
# Profit (in millions): 4430
#
#
#
# Year: 1999
#
# Rank: 4
#
# Company: Exxon Mobil
#
# Revenue (in millions): 100697
#
# Profit (in millions): 6370
#
#
#
# Year: 1999
#
# Rank: 5
#
# Company: General Electric
#
# Revenue (in millions): 100469
#
# Profit (in millions): 9296
#
#
#
# Year: 1999
#
# Rank: 6
#
# Company: Intl. Business Machines
#
# Revenue (in millions): 81667
#
# Profit (in millions): 6328
#
#
#
# Year: 1999
#
# Rank: 7
#
# Company: Citigroup
#
# Revenue (in millions): 76431
#
# Profit (in millions): 5807
#
#
#
# Year: 1999
#
# Rank: 8
#
# Company: Altria Group
#
# Revenue (in millions): 57813
#
# Profit (in millions): 5372
#
#
#
# Year: 1999
#
# Rank: 9
#
# Company: Boeing
#
# Revenue (in millions): 56154
#
# Profit (in millions): 1120
#
#
#
# Year: 1999
#
# Rank: 10
#
# Company: AT&T
#
# Revenue (in millions): 53588
#
# Profit (in millions): 6398
#
#
#
# Year: 1999
#
# Rank: 11
#
# Company: Bank of America Corp.
#
# Revenue (in millions): 50777
#
# Profit (in millions): 5165
#
#
#
# Year: 1999
#
# Rank: 12
#
# Company: State Farm Insurance Cos
#
# Revenue (in millions): 47678
#
# Profit (in millions): 1704
#
#
#
# Year: 1999
#
# Rank: 13
#
# Company: Mobil
#
# Revenue (in millions): 47061
#
# Profit (in millions): 2945
#
#
#
# Year: 1999
#
# Rank: 14
#
# Company: Hewlett-Packard
#
# Revenue (in millions): 44620.9
#
# Profit (in millions): 1319.7
#
#
#
# Year: 1999
#
# Rank: 15
#
# Company: Sears Roebuck
#
# Revenue (in millions): 41322
#
# Profit (in millions): 1048
#
#
#
# Year: 1999
#
# Rank: 16
#
# Company: DuPont
#
# Revenue (in millions): 39130
#
# Profit (in millions): 4480
#
#
#
# Year: 1999
#
# Rank: 17
#
# Company: Procter & Gamble
#
# Revenue (in millions): 37154
#
# Profit (in millions): 3780
#
#
#
# Year: 1999
#
# Rank: 18
#
# Company: TIAA-CREF
#
# Revenue (in millions): 35889.1
#
# Profit (in millions): 840.4
#
#
#
# Year: 1999
#
# Rank: 19
#
# Company: Merrill Lynch
#
# Revenue (in millions): 35853
#
# Profit (in millions): 1259
#
#
#
# Year: 1999
#
# Rank: 20
#
# Company: Prudential Ins. Co. of America
#
# Revenue (in millions): 34427
#
# Profit (in millions): 1106
#
#
#
# Year: 1999
#
# Rank: 21
#
# Company: Kmart Holding
#
# Revenue (in millions): 33674
#
# Profit (in millions): 568
#
#
#
# Year: 1999
#
# Rank: 22
#
# Company: American Intl. Group
#
# Revenue (in millions): 33296
#
# Profit (in millions): 3765.6
#
#
#
# Year: 1999
#
# Rank: 23
#
# Company: Chase Manhattan Corp.
#
# Revenue (in millions): 32379
#
# Profit (in millions): 3782
#
#
#
# Year: 1999
#
# Rank: 24
#
# Company: Texaco
#
# Revenue (in millions): 31707
#
# Profit (in millions): 578
#
#
#
# Year: 1999
#
# Rank: 25
#
# Company: Verizon Communications
#
# Revenue (in millions): 31565.9
#
# Profit (in millions): 2965.3
#
#
#
# Year: 1999
#
# Rank: 26
#
# Company: Fannie Mae
#
# Revenue (in millions): 31498.8
#
# Profit (in millions): 3418.1
#
#
#
# Year: 1999
#
# Rank: 27
#
# Company: Enron
#
# Revenue (in millions): 31260
#
# Profit (in millions): 703
#
#
#
# Year: 1999
#
# Rank: 28
#
# Company: Compaq Computer
#
# Revenue (in millions): 31169
#
# Profit (in millions): -2743
#
#
#
# Year: 1999
#
# Rank: 29
#
# Company: Morgan Stanley
#
# Revenue (in millions): 31131
#
# Profit (in millions): 3276
#
#
#
# Year: 1999
#
# Rank: 30
#
# Company: Target
#
# Revenue (in millions): 30951
#
# Profit (in millions): 935
#
#
#
# Year: 1999
#
# Rank: 31
#
# Company: J.C. Penney
#
# Revenue (in millions): 30678
#
# Profit (in millions): 594
#
#
#
# Year: 1999
#
# Rank: 32
#
# Company: Home Depot
#
# Revenue (in millions): 30219
#
# Profit (in millions): 1614
#
#
#
# Year: 1999
#
# Rank: 33
#
# Company: Lucent Technologies
#
# Revenue (in millions): 30147
#
# Profit (in millions): 970
#
#
#
# Year: 1999
#
# Rank: 34
#
# Company: Motorola
#
# Revenue (in millions): 29398
#
# Profit (in millions): -962
#
#
#
# Year: 1999
#
# Rank: 35
#
# Company: SBC Communications
#
# Revenue (in millions): 28777
#
# Profit (in millions): 4023
#
#
#
# Year: 1999
#
# Rank: 36
#
# Company: Kroger
#
# Revenue (in millions): 28203.3
#
# Profit (in millions): 410.8
#
#
#
# Year: 1999
#
# Rank: 37
#
# Company: Merck
#
# Revenue (in millions): 26898.2
#
# Profit (in millions): 5248.2
#
#
#
# Year: 1999
#
# Rank: 38
#
# Company: ChevronTexaco
#
# Revenue (in millions): 26801
#
# Profit (in millions): 1976
#
#
#
# Year: 1999
#
# Rank: 39
#
# Company: MetLife
#
# Revenue (in millions): 26735
#
# Profit (in millions): 1343
#
#
#
# Year: 1999
#
# Rank: 40
#
# Company: Intel
#
# Revenue (in millions): 26273
#
# Profit (in millions): 6068
#
#
#
# Year: 1999
#
# Rank: 41
#
# Company: Lockheed Martin
#
# Revenue (in millions): 26266
#
# Profit (in millions): 1001
#
#
#
# Year: 1999
#
# Rank: 42
#
# Company: Allstate
#
# Revenue (in millions): 25879
#
# Profit (in millions): 3294
#
#
#
# Year: 1999
#
# Rank: 43
#
# Company: United Technologies
#
# Revenue (in millions): 25715
#
# Profit (in millions): 1255
#
#
#
# Year: 1999
#
# Rank: 44
#
# Company: Bank One Corp.
#
# Revenue (in millions): 25595
#
# Profit (in millions): 3108
#
#
#
# Year: 1999
#
# Rank: 45
#
# Company: GTE
#
# Revenue (in millions): 25473
#
# Profit (in millions): 2172
#
#
#
# Year: 1999
#
# Rank: 46
#
# Company: United Parcel Service
#
# Revenue (in millions): 24788
#
# Profit (in millions): 1741
#
#
#
# Year: 1999
#
# Rank: 47
#
# Company: Marathon Oil
#
# Revenue (in millions): 24754
#
# Profit (in millions): 674
#
#
#
# Year: 1999
#
# Rank: 48
#
# Company: Safeway
#
# Revenue (in millions): 24484.2
#
# Profit (in millions): 806.7
#
#
#
# Year: 1999
#
# Rank: 49
#
# Company: Costco Wholesale
#
# Revenue (in millions): 24269.9
#
# Profit (in millions): 459.8
#
#
#
# Year: 1999
#
# Rank: 50
#
# Company: ConAgra Foods
#
# Revenue (in millions): 23840.5
#
# Profit (in millions): 613.2
#
#
#
# Year: 1999
#
# Rank: 51
#
# Company: Johnson & Johnson
#
# Revenue (in millions): 23657
#
# Profit (in millions): 3059
#
#
#
# Year: 1999
#
# Rank: 52
#
# Company: BellSouth
#
# Revenue (in millions): 23123
#
# Profit (in millions): 3527
#
#
#
# Year: 1999
#
# Rank: 53
#
# Company: Walt Disney
#
# Revenue (in millions): 22976
#
# Profit (in millions): 1850
#
#
#
# Year: 1999
#
# Rank: 54
#
# Company: PepsiCo
#
# Revenue (in millions): 22348
#
# Profit (in millions): 1993
#
#
#
# Year: 1999
#
# Rank: 55
#
# Company: Ingram Micro
#
# Revenue (in millions): 22034
#
# Profit (in millions): 245.2
#
#
#
# Year: 1999
#
# Rank: 56
#
# Company: Wachovia Corp.
#
# Revenue (in millions): 21543
#
# Profit (in millions): 2891
#
#
#
# Year: 1999
#
# Rank: 57
#
# Company: Cigna
#
# Revenue (in millions): 21437
#
# Profit (in millions): 1292
#
#
#
# Year: 1999
#
# Rank: 58
#
# Company: Caterpillar
#
# Revenue (in millions): 20977
#
# Profit (in millions): 1513
#
#
#
# Year: 1999
#
# Rank: 59
#
# Company: McKesson
#
# Revenue (in millions): 20857.3
#
# Profit (in millions): 154.9
#
#
#
# Year: 1999
#
# Rank: 60
#
# Company: Loews
#
# Revenue (in millions): 20713
#
# Profit (in millions): 464.8
#
#
#
# Year: 1999
#
# Rank: 61
#
# Company: Aetna
#
# Revenue (in millions): 20604.1
#
# Profit (in millions): 848.1
#
#
#
# Year: 1999
#
# Rank: 62
#
# Company: Wells Fargo
#
# Revenue (in millions): 20482
#
# Profit (in millions): 1950
#
#
#
# Year: 1999
#
# Rank: 63
#
# Company: Xerox
#
# Revenue (in millions): 20019
#
# Profit (in millions): 395
#
#
#
# Year: 1999
#
# Rank: 64
#
# Company: Sara Lee
#
# Revenue (in millions): 20011
#
# Profit (in millions): -523
#
#
#
# Year: 1999
#
# Rank: 65
#
# Company: PG&E Corp.
#
# Revenue (in millions): 19942
#
# Profit (in millions): 719
#
#
#
# Year: 1999
#
# Rank: 66
#
# Company: Lehman Brothers Hldgs.
#
# Revenue (in millions): 19894
#
# Profit (in millions): 736
#
#
#
# Year: 1999
#
# Rank: 67
#
# Company: American Stores
#
# Revenue (in millions): 19866.7
#
# Profit (in millions): 233.7
#
#
#
# Year: 1999
#
# Rank: 68
#
# Company: New York Life Insurance
#
# Revenue (in millions): 19848.9
#
# Profit (in millions): 752.9
#
#
#
# Year: 1999
#
# Rank: 69
#
# Company: Raytheon
#
# Revenue (in millions): 19681
#
# Profit (in millions): 379
#
#
#
# Year: 1999
#
# Rank: 70
#
# Company: International Paper
#
# Revenue (in millions): 19530
#
# Profit (in millions): 864
#
#
#
# Year: 1999
#
# Rank: 71
#
# Company: AMR
#
# Revenue (in millions): 19500
#
# Profit (in millions): 213
#
#
#
# Year: 1999
#
# Rank: 72
#
# Company: American Express
#
# Revenue (in millions): 19205
#
# Profit (in millions): 1314
#
#
#
# Year: 1999
#
# Rank: 73
#
# Company: Coca-Cola
#
# Revenue (in millions): 19132
#
# Profit (in millions): 2141
#
#
#
# Year: 1999
#
# Rank: 74
#
# Company: Columbia/HCA Healthcare
#
# Revenue (in millions): 18813
#
# Profit (in millions): 3533
#
#
#
# Year: 1999
#
# Rank: 75
#
# Company: Dow Chemical
#
# Revenue (in millions): 18441
#
# Profit (in millions): 1310
#
#
#
# Year: 1999
#
# Rank: 76
#
# Company: J.P. Morgan
#
# Revenue (in millions): 18425
#
# Profit (in millions): 963
#
#
#
# Year: 1999
#
# Rank: 77
#
# Company: Bristol-Myers Squibb
#
# Revenue (in millions): 18283.6
#
# Profit (in millions): 3141.2
#
#
#
# Year: 1999
#
# Rank: 78
#
# Company: Dell
#
# Revenue (in millions): 18243
#
# Profit (in millions): 1460
#
#
#
# Year: 1999
#
# Rank: 79
#
# Company: Freddie Mac
#
# Revenue (in millions): 18048
#
# Profit (in millions): 1700
#
#
#
# Year: 1999
#
# Rank: 80
#
# Company: MCI WorldCom
#
# Revenue (in millions): 17678
#
# Profit (in millions): -2669
#
#
#
# Year: 1999
#
# Rank: 81
#
# Company: Duke Energy
#
# Revenue (in millions): 17610
#
# Profit (in millions): 1252
#
#
#
# Year: 1999
#
# Rank: 82
#
# Company: UAL
#
# Revenue (in millions): 17561
#
# Profit (in millions): 821
#
#
#
# Year: 1999
#
# Rank: 83
#
# Company: AutoNation
#
# Revenue (in millions): 17487.3
#
# Profit (in millions): 499.5
#
#
#
# Year: 1999
#
# Rank: 84
#
# Company: UnitedHealth Group
#
# Revenue (in millions): 17355
#
# Profit (in millions): -166
#
#
#
# Year: 1999
#
# Rank: 85
#
# Company: Halliburton
#
# Revenue (in millions): 17353.1
#
# Profit (in millions): -14.7
#
#
#
# Year: 1999
#
# Rank: 86
#
# Company: Supervalu
#
# Revenue (in millions): 17201.4
#
# Profit (in millions): 230.8
#
#
#
# Year: 1999
#
# Rank: 87
#
# Company: Ameritech
#
# Revenue (in millions): 17154
#
# Profit (in millions): 3606
#
#
#
# Year: 1999
#
# Rank: 88
#
# Company: Sprint
#
# Revenue (in millions): 17134.3
#
# Profit (in millions): 414.5
#
#
#
# Year: 1999
#
# Rank: 89
#
# Company: Nabisco Group Holdings
#
# Revenue (in millions): 17037
#
# Profit (in millions): -577
#
#
#
# Year: 1999
#
# Rank: 90
#
# Company: Electronic Data Systems
#
# Revenue (in millions): 16891
#
# Profit (in millions): 743.4
#
#
#
# Year: 1999
#
# Rank: 91
#
# Company: Archer Daniels Midland
#
# Revenue (in millions): 16108.6
#
# Profit (in millions): 403.6
#
#
#
# Year: 1999
#
# Rank: 92
#
# Company: Albertson's
#
# Revenue (in millions): 16005.1
#
# Profit (in millions): 567.2
#
#
#
# Year: 1999
#
# Rank: 93
#
# Company: Cardinal Health
#
# Revenue (in millions): 15918.1
#
# Profit (in millions): 247.1
#
#
#
# Year: 1999
#
# Rank: 94
#
# Company: FedEx
#
# Revenue (in millions): 15872.8
#
# Profit (in millions): 503
#
#
#
# Year: 1999
#
# Rank: 95
#
# Company: Federated Dept. Stores
#
# Revenue (in millions): 15833
#
# Profit (in millions): 662
#
#
#
# Year: 1999
#
# Rank: 96
#
# Company: Alcoa
#
# Revenue (in millions): 15489.4
#
# Profit (in millions): 853
#
#
#
# Year: 1999
#
# Rank: 97
#
# Company: Sysco
#
# Revenue (in millions): 15327.5
#
# Profit (in millions): 296.8
#
#
#
# Year: 1999
#
# Rank: 98
#
# Company: Walgreen
#
# Revenue (in millions): 15307
#
# Profit (in millions): 511
#
#
#
# Year: 1999
#
# Rank: 99
#
# Company: CVS
#
# Revenue (in millions): 15273.6
#
# Profit (in millions): 396.4
#
#
#
# Year: 1999
#
# Rank: 100
#
# Company: Honeywell Intl.
#
# Revenue (in millions): 15128
#
# Profit (in millions): 1331
#
#
#
# Year: 1999
#
# Rank: 101
#
# Company: Fleming
#
# Revenue (in millions): 15069.3
#
# Profit (in millions): -510.6
#
#
#
# Year: 1999
#
# Rank: 102
#
# Company: Hartford Financial Services
#
# Revenue (in millions): 15022
#
# Profit (in millions): 1015
#
#
#
# Year: 1999
#
# Rank: 103
#
# Company: 3M
#
# Revenue (in millions): 15021
#
# Profit (in millions): 1175
#
#
#
# Year: 1999
#
# Rank: 104
#
# Company: Fred Meyer
#
# Revenue (in millions): 14878.8
#
# Profit (in millions): -162.8
#
#
#
# Year: 1999
#
# Rank: 105
#
# Company: TXU
#
# Revenue (in millions): 14736
#
# Profit (in millions): 740
#
#
#
# Year: 1999
#
# Rank: 106
#
# Company: Pfizer
#
# Revenue (in millions): 14704
#
# Profit (in millions): 3351
#
#
#
# Year: 1999
#
# Rank:
#
# Company: Northwestern Mutual
#
# Revenue (in millions): 14644.9
#
# Profit (in millions): 808.9
#
#
#
# Year: 1999
#
# Rank: 108
#
# Company: Time Warner
#
# Revenue (in millions): 14582
#
# Profit (in millions): 168
#
#
#
# Year: 1999
#
# Rank: 109
#
# Company: Microsoft
#
# Revenue (in millions): 14484
#
# Profit (in millions): 4490
#
#
#
# Year: 1999
#
# Rank: 110
#
# Company: Dynegy
#
# Revenue (in millions): 14258
#
# Profit (in millions): 108.4
#
#
#
# Year: 1999
#
# Rank: 111
#
# Company: Delta Air Lines
#
# Revenue (in millions): 14138
#
# Profit (in millions): 1001
#
#
#
# Year: 1999
#
# Rank: 112
#
# Company: Berkshire Hathaway
#
# Revenue (in millions): 13832
#
# Profit (in millions): 2830
#
#
#
# Year: 1999
#
# Rank: 113
#
# Company: Deere
#
# Revenue (in millions): 13821.5
#
# Profit (in millions): 1021.4
#
#
#
# Year: 1999
#
# Rank: 114
#
# Company: Bergen Brunswig
#
# Revenue (in millions): 13720
#
# Profit (in millions): 3.1
#
#
#
# Year: 1999
#
# Rank: 115
#
# Company: Winn-Dixie Stores
#
# Revenue (in millions): 13617.5
#
# Profit (in millions): 198.6
#
#
#
# Year: 1999
#
# Rank: 116
#
# Company: Massey Energy
#
# Revenue (in millions): 13504.8
#
# Profit (in millions): 235.5
#
#
#
# Year: 1999
#
# Rank: 117
#
# Company: Wyeth
#
# Revenue (in millions): 13462.7
#
# Profit (in millions): 2474.3
#
#
#
# Year: 1999
#
# Rank: 118
#
# Company: Emerson Electric
#
# Revenue (in millions): 13447.2
#
# Profit (in millions): 1228.6
#
#
#
# Year: 1999
#
# Rank: 119
#
# Company: Coca-Cola Enterprises
#
# Revenue (in millions): 13414
#
# Profit (in millions): 142
#
#
#
# Year: 1999
#
# Rank: 120
#
# Company: May Dept. Stores
#
# Revenue (in millions): 13413
#
# Profit (in millions): 849
#
#
#
# Year: 1999
#
# Rank: 121
#
# Company: Eastman Kodak
#
# Revenue (in millions): 13406
#
# Profit (in millions): 1390
#
#
#
# Year: 1999
#
# Rank: 122
#
# Company: Georgia-Pacific
#
# Revenue (in millions): 13223
#
# Profit (in millions): 98
#
#
#
# Year: 1999
#
# Rank: 123
#
# Company: Atlantic Richfield
#
# Revenue (in millions): 13195
#
# Profit (in millions): 452
#
#
#
# Year: 1999
#
# Rank: 124
#
# Company: Liberty Mutual Ins. Group
#
# Revenue (in millions): 13166
#
# Profit (in millions): 385
#
#
#
# Year: 1999
#
# Rank: 125
#
# Company: Nationwide
#
# Revenue (in millions): 13105
#
# Profit (in millions): 1195.7
#
#
#
# Year: 1999
#
# Rank: 126
#
# Company: IBP
#
# Revenue (in millions): 12848.6
#
# Profit (in millions): 190
#
#
#
# Year: 1999
#
# Rank: 127
#
# Company: Dana
#
# Revenue (in millions): 12838.7
#
# Profit (in millions): 534.1
#
#
#
# Year: 1999
#
# Rank: 128
#
# Company: Washington Mutual
#
# Revenue (in millions): 12745.6
#
# Profit (in millions): 1486.9
#
#
#
# Year: 1999
#
# Rank: 129
#
# Company: Waste Management
#
# Revenue (in millions): 12703.5
#
# Profit (in millions): -770.7
#
#
#
# Year: 1999
#
# Rank: 130
#
# Company: Goodyear Tire & Rubber
#
# Revenue (in millions): 12648.7
#
# Profit (in millions): 682.3
#
#
#
# Year: 1999
#
# Rank: 131
#
# Company: Johnson Controls
#
# Revenue (in millions): 12586.8
#
# Profit (in millions): 337.7
#
#
#
# Year: 1999
#
# Rank: 132
#
# Company: Aquila
#
# Revenue (in millions): 12563.4
#
# Profit (in millions): 132.2
#
#
#
# Year: 1999
#
# Rank: 133
#
# Company: Abbott Laboratories
#
# Revenue (in millions): 12477.8
#
# Profit (in millions): 2333.2
#
#
#
# Year: 1999
#
# Rank: 134
#
# Company: McDonald's
#
# Revenue (in millions): 12421.4
#
# Profit (in millions): 1550.1
#
#
#
# Year: 1999
#
# Rank: 135
#
# Company: US West
#
# Revenue (in millions): 12378
#
# Profit (in millions): 1508
#
#
#
# Year: 1999
#
# Rank: 136
#
# Company: Kimberly-Clark
#
# Revenue (in millions): 12297.8
#
# Profit (in millions): 1165.8
#
#
#
# Year: 1999
#
# Rank: 137
#
# Company: Lowe's
#
# Revenue (in millions): 12244.9
#
# Profit (in millions): 482.4
#
#
#
# Year: 1999
#
# Rank: 138
#
# Company: Viacom
#
# Revenue (in millions): 12096.1
#
# Profit (in millions): -122.4
#
#
#
# Year: 1999
#
# Rank: 139
#
# Company: Publix Super Markets
#
# Revenue (in millions): 12067.1
#
# Profit (in millions): 378.3
#
#
#
# Year: 1999
#
# Rank: 140
#
# Company: Bankers Trust Corp.
#
# Revenue (in millions): 12048
#
# Profit (in millions): -73
#
#
#
# Year: 1999
#
# Rank: 141
#
# Company: Tosco
#
# Revenue (in millions): 12021.5
#
# Profit (in millions): 106.2
#
#
#
# Year: 1999
#
# Rank: 142
#
# Company: TRW
#
# Revenue (in millions): 11886
#
# Profit (in millions): 477
#
#
#
# Year: 1999
#
# Rank: 143
#
# Company: ConocoPhillips
#
# Revenue (in millions): 11845
#
# Profit (in millions): 237
#
#
#
# Year: 1999
#
# Rank: 144
#
# Company: Textron
#
# Revenue (in millions): 11549
#
# Profit (in millions): 608
#
#
#
# Year: 1999
#
# Rank: 145
#
# Company:
#
# Revenue (in millions): 11529
#
# Profit (in millions): 129
#
#
#
# Year: 1999
#
# Rank: 146
#
# Company: Entergy
#
# Revenue (in millions): 11494.8
#
# Profit (in millions): 785.6
#
#
#
# Year: 1999
#
# Rank: 147
#
# Company: CenterPoint Energy
#
# Revenue (in millions): 11488.5
#
# Profit (in millions): -141.1
#
#
#
# Year: 1999
#
# Rank: 148
#
# Company: Southern
#
# Revenue (in millions): 11403
#
# Profit (in millions): 977
#
#
#
# Year: 1999
#
# Rank: 149
#
# Company: Rite Aid
#
# Revenue (in millions): 11375.1
#
# Profit (in millions): 316.4
#
#
#
# Year: 1999
#
# Rank: 150
#
# Company: Anheuser-Busch
#
# Revenue (in millions): 11245.8
#
# Profit (in millions): 1233.3
#
#
#
# Year: 1999
#
# Rank: 151
#
# Company: Toys `R` Us
#
# Revenue (in millions): 11200
#
# Profit (in millions): -132
#
#
#
# Year: 1999
#
# Rank: 152
#
# Company: Weyerhaeuser
#
# Revenue (in millions): 10766
#
# Profit (in millions): 294
#
#
#
# Year: 1999
#
# Rank: 153
#
# Company: Mass. Mutual Life Ins.
#
# Revenue (in millions): 10668.1
#
# Profit (in millions): 432.8
#
#
#
# Year: 1999
#
# Rank: 154
#
# Company: Union Pacific
#
# Revenue (in millions): 10553
#
# Profit (in millions): -633
#
#
#
# Year: 1999
#
# Rank: 155
#
# Company: Whirlpool
#
# Revenue (in millions): 10323
#
# Profit (in millions): 325
#
#
#
# Year: 1999
#
# Rank: 156
#
# Company: American General
#
# Revenue (in millions): 10251
#
# Profit (in millions): 764
#
#
#
# Year: 1999
#
# Rank: 157
#
# Company: Warner-Lambert
#
# Revenue (in millions): 10213.7
#
# Profit (in millions): 1254
#
#
#
# Year: 1999
#
# Rank: 158
#
# Company: Edison International
#
# Revenue (in millions): 10208
#
# Profit (in millions): 668
#
#
#
# Year: 1999
#
# Rank: 159
#
# Company: Gillette
#
# Revenue (in millions): 10056
#
# Profit (in millions): 1081
#
#
#
# Year: 1999
#
# Rank: 160
#
# Company: Eli Lilly
#
# Revenue (in millions): 10051.3
#
# Profit (in millions): 2097.9
#
#
#
# Year: 1999
#
# Rank: 161
#
# Company: FleetBoston Financial
#
# Revenue (in millions): 10002
#
# Profit (in millions): 1532
#
#
#
# Year: 1999
#
# Rank: 162
#
# Company: CSX
#
# Revenue (in millions): 9898
#
# Profit (in millions): 537
#
#
#
# Year: 1999
#
# Rank: 163
#
# Company: Tenet Healthcare
#
# Revenue (in millions): 9895
#
# Profit (in millions): 261
#
#
#
# Year: 1999
#
# Rank: 164
#
# Company: Sun Microsystems
#
# Revenue (in millions): 9790.8
#
# Profit (in millions): 762.9
#
#
#
# Year: 1999
#
# Rank: 165
#
# Company: Humana
#
# Revenue (in millions): 9781
#
# Profit (in millions): 129
#
#
#
# Year: 1999
#
# Rank: 166
#
# Company: Nike
#
# Revenue (in millions): 9553.1
#
# Profit (in millions): 399.6
#
#
#
# Year: 1999
#
# Rank: 167
#
# Company: PacifiCare Health Sys.
#
# Revenue (in millions): 9521.5
#
# Profit (in millions): 202.4
#
#
#
# Year: 1999
#
# Rank: 168
#
# Company: PacifiCorp
#
# Revenue (in millions): 9442.5
#
# Profit (in millions): 312
#
#
#
# Year: 1999
#
# Rank: 169
#
# Company: Limited Brands
#
# Revenue (in millions): 9346.9
#
# Profit (in millions): 2053.6
#
#
#
# Year: 1999
#
# Rank: 170
#
# Company: H.J. Heinz
#
# Revenue (in millions): 9209.3
#
# Profit (in millions): 801.6
#
#
#
# Year: 1999
#
# Rank: 171
#
# Company: St. Paul Travelers Cos.
#
# Revenue (in millions): 9108.4
#
# Profit (in millions): 89.3
#
#
#
# Year: 1999
#
# Rank: 172
#
# Company: CBS
#
# Revenue (in millions): 9061
#
# Profit (in millions): -21
#
#
#
# Year: 1999
#
# Rank: 173
#
# Company: Lear
#
# Revenue (in millions): 9059.4
#
# Profit (in millions): 115.5
#
#
#
# Year: 1999
#
# Rank: 174
#
# Company: Gap
#
# Revenue (in millions): 9054.5
#
# Profit (in millions): 824.5
#
#
#
# Year: 1999
#
# Rank: 175
#
# Company: Northwest Airlines
#
# Revenue (in millions): 9044.8
#
# Profit (in millions): -285.5
#
#
#
# Year: 1999
#
# Rank: 176
#
# Company: Office Depot
#
# Revenue (in millions): 8997.7
#
# Profit (in millions): 233.2
#
#
#
# Year: 1999
#
# Rank: 177
#
# Company: Colgate-Palmolive
#
# Revenue (in millions): 8971.6
#
# Profit (in millions): 848.6
#
#
#
# Year: 1999
#
# Rank:
#
# Company: Burlington No. Santa Fe
#
# Revenue (in millions): 8941
#
# Profit (in millions): 1155
#
#
#
# Year: 1999
#
# Rank: 179
#
# Company: John Hancock Financial Svcs.
#
# Revenue (in millions): 8911.7
#
# Profit (in millions): 627.3
#
#
#
# Year: 1999
#
# Rank: 180
#
# Company: Northrop Grumman
#
# Revenue (in millions): 8902
#
# Profit (in millions): 214
#
#
#
# Year: 1999
#
# Rank: 181
#
# Company: Health Net
#
# Revenue (in millions): 8896.1
#
# Profit (in millions): -165.2
#
#
#
# Year: 1999
#
# Rank: 182
#
# Company: Circuit City Stores
#
# Revenue (in millions): 8870.8
#
# Profit (in millions): 104.3
#
#
#
# Year: 1999
#
# Rank: 183
#
# Company: Manpower
#
# Revenue (in millions): 8814.3
#
# Profit (in millions): 75.7
#
#
#
# Year: 1999
#
# Rank: 184
#
# Company: Farmland Industries
#
# Revenue (in millions): 8775
#
# Profit (in millions): N.A.
#
#
#
# Year: 1999
#
# Rank: 185
#
# Company: Household International
#
# Revenue (in millions): 8707.6
#
# Profit (in millions): 524.1
#
#
#
# Year: 1999
#
# Rank: 186
#
# Company: US Airways Group
#
# Revenue (in millions): 8688
#
# Profit (in millions): 538
#
#
#
# Year: 1999
#
# Rank: 187
#
# Company: Monsanto
#
# Revenue (in millions): 8648
#
# Profit (in millions): -250
#
#
#
# Year: 1999
#
# Rank: 188
#
# Company: AmerisourceBergen
#
# Revenue (in millions): 8575.4
#
# Profit (in millions): 50.5
#
#
#
# Year: 1999
#
# Rank: 189
#
# Company: CHS Electronics
#
# Revenue (in millions): 8545.8
#
# Profit (in millions): 45.7
#
#
#
# Year: 1999
#
# Rank: 190
#
# Company: Yum Brands
#
# Revenue (in millions): 8468
#
# Profit (in millions): 445
#
#
#
# Year: 1999
#
# Rank: 191
#
# Company: Texas Instruments
#
# Revenue (in millions): 8460
#
# Profit (in millions): 407
#
#
#
# Year: 1999
#
# Rank: 192
#
# Company: Cisco Systems
#
# Revenue (in millions): 8458.8
#
# Profit (in millions): 1350.1
#
#
#
# Year: 1999
#
# Rank: 193
#
# Company: Honeywell
#
# Revenue (in millions): 8426.7
#
# Profit (in millions): 572
#
#
#
# Year: 1999
#
# Rank: 194
#
# Company: Bestfoods
#
# Revenue (in millions): 8374
#
# Profit (in millions): 624
#
#
#
# Year: 1999
#
# Rank: 195
#
# Company: Best Buy
#
# Revenue (in millions): 8358.2
#
# Profit (in millions): 94.5
#
#
#
# Year: 1999
#
# Rank: 196
#
# Company: Ultramar Diamond Shamrock
#
# Revenue (in millions): 8346.5
#
# Profit (in millions): -78.1
#
#
#
# Year: 1999
#
# Rank: 197
#
# Company: Arrow Electronics
#
# Revenue (in millions): 8344.7
#
# Profit (in millions): 145.8
#
#
#
# Year: 1999
#
# Rank: 198
#
# Company: Crown Holdings
#
# Revenue (in millions): 8300
#
# Profit (in millions): 105.1
#
#
#
# Year: 1999
#
# Rank: 199
#
# Company: Ingersoll-Rand
#
# Revenue (in millions): 8291.5
#
# Profit (in millions): 509.1
#
#
#
# Year: 1999
#
# Rank: 200
#
# Company: Schering-Plough
#
# Revenue (in millions): 8077
#
# Profit (in millions): 1756
#
#
#
# Year: 1999
#
# Rank: 201
#
# Company: National City Corp.
#
# Revenue (in millions): 8070.8
#
# Profit (in millions): 1070.7
#
#
#
# Year: 1999
#
# Rank: 202
#
# Company: Rockwell Automation
#
# Revenue (in millions): 8025
#
# Profit (in millions): -427
#
#
#
# Year: 1999
#
# Rank: 203
#
# Company: Dillard's
#
# Revenue (in millions): 8012
#
# Profit (in millions): 135
#
#
#
# Year: 1999
#
# Rank: 204
#
# Company: Bear Stearns
#
# Revenue (in millions): 7979.9
#
# Profit (in millions): 660.4
#
#
#
# Year: 1999
#
# Rank: 205
#
# Company: Guardian Life of America
#
# Revenue (in millions): 7973.8
#
# Profit (in millions): 160.4
#
#
#
# Year: 1999
#
# Rank: 206
#
# Company: Marriott International
#
# Revenue (in millions): 7968
#
# Profit (in millions): 390
#
#
#
# Year: 1999
#
# Rank: 207
#
# Company: Continental Airlines
#
# Revenue (in millions): 7951
#
# Profit (in millions): 383
#
#
#
# Year: 1999
#
# Rank: 208
#
# Company: TJX
#
# Revenue (in millions): 7949.1
#
# Profit (in millions): 424.2
#
#
#
# Year: 1999
#
# Rank: 209
#
# Company: PNC Financial Services
#
# Revenue (in millions): 7936
#
# Profit (in millions): 1115
#
#
#
# Year: 1999
#
# Rank: 210
#
# Company: Paccar
#
# Revenue (in millions): 7894.8
#
# Profit (in millions): 416.8
#
#
#
# Year: 1999
#
# Rank: 211
#
# Company: Navistar International
#
# Revenue (in millions): 7885
#
# Profit (in millions): 299
#
#
#
# Year: 1999
#
# Rank: 212
#
# Company: Conseco
#
# Revenue (in millions): 7716
#
# Profit (in millions): 588.1
#
#
#
# Year: 1999
#
# Rank: 213
#
# Company: Principal Financial
#
# Revenue (in millions): 7697.4
#
# Profit (in millions): 693
#
#
#
# Year: 1999
#
# Rank: 214
#
# Company: USAA
#
# Revenue (in millions): 7687.4
#
# Profit (in millions): 979.5
#
#
#
# Year: 1999
#
# Rank: 215
#
# Company: U.S. Bancorp
#
# Revenue (in millions): 7664
#
# Profit (in millions): 1327.4
#
#
#
# Year: 1999
#
# Rank: 216
#
# Company: Williams
#
# Revenue (in millions): 7658.3
#
# Profit (in millions): 127.5
#
#
#
# Year: 1999
#
# Rank: 217
#
# Company: Bindley Western
#
# Revenue (in millions): 7623.1
#
# Profit (in millions): 19.1
#
#
#
# Year: 1999
#
# Rank: 218
#
# Company: BankBoston Corp.
#
# Revenue (in millions): 7609
#
# Profit (in millions): 792
#
#
#
# Year: 1999
#
# Rank: 219
#
# Company: Tenneco Automotive
#
# Revenue (in millions): 7605
#
# Profit (in millions): 255
#
#
#
# Year: 1999
#
# Rank: 220
#
# Company: ITT Industries
#
# Revenue (in millions): 7523.1
#
# Profit (in millions): 1532.5
#
#
#
# Year: 1999
#
# Rank: 221
#
# Company: PPG Industries
#
# Revenue (in millions): 7510
#
# Profit (in millions): 801
#
#
#
# Year: 1999
#
# Rank: 222
#
# Company: Campbell Soup
#
# Revenue (in millions): 7505
#
# Profit (in millions): 660
#
#
#
# Year: 1999
#
# Rank: 223
#
# Company: Gateway
#
# Revenue (in millions): 7467.9
#
# Profit (in millions): 346.4
#
#
#
# Year: 1999
#
# Rank: 224
#
# Company: Nebco Evans
#
# Revenue (in millions): 7421
#
# Profit (in millions): -152.3
#
#
#
# Year: 1999
#
# Rank: 225
#
# Company: Unisource
#
# Revenue (in millions): 7417.3
#
# Profit (in millions): -231.8
#
#
#
# Year: 1999
#
# Rank: 226
#
# Company: Tyson Foods
#
# Revenue (in millions): 7414.1
#
# Profit (in millions): 25.1
#
#
#
# Year: 1999
#
# Rank: 227
#
# Company: SunTrust Banks
#
# Revenue (in millions): 7392.1
#
# Profit (in millions): 971
#
#
#
# Year: 1999
#
# Rank: 228
#
# Company: Tele-Communications
#
# Revenue (in millions): 7351
#
# Profit (in millions): 1943
#
#
#
# Year: 1999
#
# Rank: 229
#
# Company: Fort James
#
# Revenue (in millions): 7301.1
#
# Profit (in millions): 497.6
#
#
#
# Year: 1999
#
# Rank: 230
#
# Company: Paine Webber Group
#
# Revenue (in millions): 7249.6
#
# Profit (in millions): 433.6
#
#
#
# Year: 1999
#
# Rank: 231
#
# Company: Unisys
#
# Revenue (in millions): 7208.4
#
# Profit (in millions): 387
#
#
#
# Year: 1999
#
# Rank: 232
#
# Company: Marsh & McLennan
#
# Revenue (in millions): 7190
#
# Profit (in millions): 796
#
#
#
# Year: 1999
#
# Rank: 233
#
# Company: Unicom
#
# Revenue (in millions): 7151.3
#
# Profit (in millions): 510.2
#
#
#
# Year: 1999
#
# Rank: 234
#
# Company: Oracle
#
# Revenue (in millions): 7143.9
#
# Profit (in millions): 813.7
#
#
#
# Year: 1999
#
# Rank: 235
#
# Company: Coastal
#
# Revenue (in millions): 7125.2
#
# Profit (in millions): 444.4
#
#
#
# Year: 1999
#
# Rank: 236
#
# Company: Staples
#
# Revenue (in millions): 7123.2
#
# Profit (in millions): 185.4
#
#
#
# Year: 1999
#
# Rank: 237
#
# Company: AFLAC
#
# Revenue (in millions): 7104.2
#
# Profit (in millions): 486.8
#
#
#
# Year: 1999
#
# Rank: 238
#
# Company: KeyCorp
#
# Revenue (in millions): 7100
#
# Profit (in millions): 996
#
#
#
# Year: 1999
#
# Rank: 239
#
# Company: Consolidated Edison
#
# Revenue (in millions): 7093
#
# Profit (in millions): 729.7
#
#
#
# Year: 1999
#
# Rank: 240
#
# Company: Sunoco
#
# Revenue (in millions): 7024
#
# Profit (in millions): 280
#
#
#
# Year: 1999
#
# Rank: 241
#
# Company: Caremark Rx
#
# Revenue (in millions): 7003.6
#
# Profit (in millions): -1260.5
#
#
#
# Year: 1999
#
# Rank: 242
#
# Company: Ashland
#
# Revenue (in millions): 6933
#
# Profit (in millions): 203
#
#
#
# Year: 1999
#
# Rank: 243
#
# Company: Pharmacia
#
# Revenue (in millions): 6893
#
# Profit (in millions): 691
#
#
#
# Year: 1999
#
# Rank: 244
#
# Company: Seagate Technology
#
# Revenue (in millions): 6819
#
# Profit (in millions): -530
#
#
#
# Year: 1999
#
# Rank: 245
#
# Company: SCI Systems
#
# Revenue (in millions): 6805.9
#
# Profit (in millions): 145.1
#
#
#
# Year: 1999
#
# Rank: 246
#
# Company: Kellogg
#
# Revenue (in millions): 6762.1
#
# Profit (in millions): 502.6
#
#
#
# Year: 1999
#
# Rank: 247
#
# Company: Sodexho Marriott Services
#
# Revenue (in millions): 6704
#
# Profit (in millions): 122
#
#
#
# Year: 1999
#
# Rank: 248
#
# Company: FPL Group
#
# Revenue (in millions): 6661
#
# Profit (in millions): 664
#
#
#
# Year: 1999
#
# Rank: 249
#
# Company: American Standard
#
# Revenue (in millions): 6653.9
#
# Profit (in millions): -16.3
#
#
#
# Year: 1999
#
# Rank: 250
#
# Company: Eaton
#
# Revenue (in millions): 6625
#
# Profit (in millions): 349
#
#
#
# Year: 1999
#
# Rank: 251
#
# Company: Amerada Hess
#
# Revenue (in millions): 6617.5
#
# Profit (in millions): -458.9
#
#
#
# Year: 1999
#
# Rank: 252
#
# Company: Genuine Parts
#
# Revenue (in millions): 6614
#
# Profit (in millions): 355.8
#
#
#
# Year: 1999
#
# Rank: 253
#
# Company: Computer Sciences
#
# Revenue (in millions): 6600.8
#
# Profit (in millions): 260.4
#
#
#
# Year: 1999
#
# Rank: 254
#
# Company: Baxter International
#
# Revenue (in millions): 6599
#
# Profit (in millions): 315
#
#
#
# Year: 1999
#
# Rank: 255
#
# Company: Occidental Petroleum
#
# Revenue (in millions): 6596
#
# Profit (in millions): 363
#
#
#
# Year: 1999
#
# Rank: 256
#
# Company: WellPoint Health Networks
#
# Revenue (in millions): 6573
#
# Profit (in millions): 231.3
#
#
#
# Year: 1999
#
# Rank: 257
#
# Company: Columbia Energy Group
#
# Revenue (in millions): 6568.2
#
# Profit (in millions): 269.2
#
#
#
# Year: 1999
#
# Rank: 258
#
# Company: NCR
#
# Revenue (in millions): 6505
#
# Profit (in millions): 122
#
#
#
# Year: 1999
#
# Rank: 259
#
# Company: Aon
#
# Revenue (in millions): 6492.9
#
# Profit (in millions): 540.5
#
#
#
# Year: 1999
#
# Rank: 260
#
# Company: Safeco
#
# Revenue (in millions): 6452.1
#
# Profit (in millions): 351.9
#
#
#
# Year: 1999
#
# Rank: 261
#
# Company: Transamerica
#
# Revenue (in millions): 6428.6
#
# Profit (in millions): 707
#
#
#
# Year: 1999
#
# Rank: 262
#
# Company: Aramark
#
# Revenue (in millions): 6377.3
#
# Profit (in millions): 129.2
#
#
#
# Year: 1999
#
# Rank: 263
#
# Company: Chubb
#
# Revenue (in millions): 6349.8
#
# Profit (in millions): 707
#
#
#
# Year: 1999
#
# Rank: 264
#
# Company: American Electric Power
#
# Revenue (in millions): 6345.9
#
# Profit (in millions): 536.2
#
#
#
# Year: 1999
#
# Rank: 265
#
# Company: Baker Hughes
#
# Revenue (in millions): 6311.9
#
# Profit (in millions): -297.4
#
#
#
# Year: 1999
#
# Rank: 266
#
# Company: Cummins
#
# Revenue (in millions): 6266
#
# Profit (in millions): -21
#
#
#
# Year: 1999
#
# Rank: 267
#
# Company: Saks
#
# Revenue (in millions): 6219.9
#
# Profit (in millions): -0.9
#
#
#
# Year: 1999
#
# Rank: 268
#
# Company: OfficeMax
#
# Revenue (in millions): 6162.1
#
# Profit (in millions): -37
#
#
#
# Year: 1999
#
# Rank: 269
#
# Company: Case
#
# Revenue (in millions): 6149
#
# Profit (in millions): 64
#
#
#
# Year: 1999
#
# Rank: 270
#
# Company: Lincoln National
#
# Revenue (in millions): 6087.1
#
# Profit (in millions): 509.8
#
#
#
# Year: 1999
#
# Rank: 271
#
# Company: Dominion Resources
#
# Revenue (in millions): 6086.2
#
# Profit (in millions): 535.6
#
#
#
# Year: 1999
#
# Rank:
#
# Company: General Mills
#
# Revenue (in millions): 6033
#
# Profit (in millions): 421.8
#
#
#
# Year: 1999
#
# Rank: 273
#
# Company: Apple Computer
#
# Revenue (in millions): 5941
#
# Profit (in millions): 309
#
#
#
# Year: 1999
#
# Rank: 274
#
# Company: Public Service Enterprise Group
#
# Revenue (in millions): 5931
#
# Profit (in millions): 644
#
#
#
# Year: 1999
#
# Rank: 275
#
# Company: Avnet
#
# Revenue (in millions): 5916.3
#
# Profit (in millions): 151.4
#
#
#
# Year: 1999
#
# Rank: 276
#
# Company: Wachovia Corp.
#
# Revenue (in millions): 5913.8
#
# Profit (in millions): 874.2
#
#
#
# Year: 1999
#
# Rank: 277
#
# Company: R.R. Donnelley & Sons
#
# Revenue (in millions): 5899.9
#
# Profit (in millions): 294.6
#
#
#
# Year: 1999
#
# Rank: 278
#
# Company: Wellpoint
#
# Revenue (in millions): 5878.2
#
# Profit (in millions): 172.4
#
#
#
# Year: 1999
#
# Rank: 279
#
# Company: Cinergy
#
# Revenue (in millions): 5876.3
#
# Profit (in millions): 261
#
#
#
# Year: 1999
#
# Rank: 280
#
# Company: FirstEnergy
#
# Revenue (in millions): 5861.3
#
# Profit (in millions): 410.9
#
#
#
# Year: 1999
#
# Rank: 281
#
# Company: Reynolds Metals
#
# Revenue (in millions): 5859
#
# Profit (in millions): 66
#
#
#
# Year: 1999
#
# Rank: 282
#
# Company: Cendant
#
# Revenue (in millions): 5832
#
# Profit (in millions): 539.6
#
#
#
# Year: 1999
#
# Rank: 283
#
# Company: Mellon Financial Corp.
#
# Revenue (in millions): 5814
#
# Profit (in millions): 870
#
#
#
# Year: 1999
#
# Rank: 284
#
# Company: Quantum
#
# Revenue (in millions): 5805.2
#
# Profit (in millions): 170.8
#
#
#
# Year: 1999
#
# Rank: 285
#
# Company: Bank of New York Co.
#
# Revenue (in millions): 5793
#
# Profit (in millions): 1192
#
#
#
# Year: 1999
#
# Rank: 286
#
# Company: El Paso
#
# Revenue (in millions): 5782
#
# Profit (in millions): 225
#
#
#
# Year: 1999
#
# Rank: 287
#
# Company: Foot Locker
#
# Revenue (in millions): 5698
#
# Profit (in millions): -136
#
#
#
# Year: 1999
#
# Rank: 288
#
# Company: Union Carbide
#
# Revenue (in millions): 5659
#
# Profit (in millions): 403
#
#
#
# Year: 1999
#
# Rank: 289
#
# Company: Champion International
#
# Revenue (in millions): 5653
#
# Profit (in millions): 75.3
#
#
#
# Year: 1999
#
# Rank: 290
#
# Company: Illinois Tool Works
#
# Revenue (in millions): 5647.9
#
# Profit (in millions): 672.8
#
#
#
# Year: 1999
#
# Rank: 291
#
# Company: Ikon Office Solutions
#
# Revenue (in millions): 5628.7
#
# Profit (in millions): -83.1
#
#
#
# Year: 1999
#
# Rank: 292
#
# Company: Comcast
#
# Revenue (in millions): 5590.5
#
# Profit (in millions): 972.1
#
#
#
# Year: 1999
#
# Rank: 293
#
# Company: Ralston Purina
#
# Revenue (in millions): 5577
#
# Profit (in millions): 1105.7
#
#
#
# Year: 1999
#
# Rank: 294
#
# Company: Valero Energy
#
# Revenue (in millions): 5539.3
#
# Profit (in millions): -47.3
#
#
#
# Year: 1999
#
# Rank: 295
#
# Company: LG&E Energy
#
# Revenue (in millions): 5528.7
#
# Profit (in millions): -95.5
#
#
#
# Year: 1999
#
# Rank: 296
#
# Company: Sempra Energy
#
# Revenue (in millions): 5525
#
# Profit (in millions): 294
#
#
#
# Year: 1999
#
# Rank: 297
#
# Company: MicroAge
#
# Revenue (in millions): 5520
#
# Profit (in millions): -8.3
#
#
#
# Year: 1999
#
# Rank: 298
#
# Company: U.S. Foodservice
#
# Revenue (in millions): 5506.9
#
# Profit (in millions): -47
#
#
#
# Year: 1999
#
# Rank: 299
#
# Company: AMP
#
# Revenue (in millions): 5482
#
# Profit (in millions): 2
#
#
#
# Year: 1999
#
# Rank: 300
#
# Company: Central & South West
#
# Revenue (in millions): 5482
#
# Profit (in millions): 440
#
#
#
# Year: 1999
#
# Rank: 301
#
# Company: VF
#
# Revenue (in millions): 5478.8
#
# Profit (in millions): 388.3
#
#
#
# Year: 1999
#
# Rank: 302
#
# Company: Owens-Illinois
#
# Revenue (in millions): 5449.9
#
# Profit (in millions): 108
#
#
#
# Year: 1999
#
# Rank: 303
#
# Company: 3Com
#
# Revenue (in millions): 5420.4
#
# Profit (in millions): 30.2
#
#
#
# Year: 1999
#
# Rank: 304
#
# Company: Unocal
#
# Revenue (in millions): 5379
#
# Profit (in millions): 130
#
#
#
# Year: 1999
#
# Rank: 305
#
# Company: Progressive
#
# Revenue (in millions): 5292.4
#
# Profit (in millions): 456.7
#
#
#
# Year: 1999
#
# Rank: 306
#
# Company: Solectron
#
# Revenue (in millions): 5288.3
#
# Profit (in millions): 198.8
#
#
#
# Year: 1999
#
# Rank: 307
#
# Company: CompUSA
#
# Revenue (in millions): 5286
#
# Profit (in millions): 31.5
#
#
#
# Year: 1999
#
# Rank: 308
#
# Company: Avon Products
#
# Revenue (in millions): 5212.7
#
# Profit (in millions): 270
#
#
#
# Year: 1999
#
# Rank: 309
#
# Company: Exelon
#
# Revenue (in millions): 5210.5
#
# Profit (in millions): 512.7
#
#
#
# Year: 1999
#
# Rank: 310
#
# Company: MBNA
#
# Revenue (in millions): 5195.1
#
# Profit (in millions): 776.3
#
#
#
# Year: 1999
#
# Rank: 311
#
# Company: Alltel
#
# Revenue (in millions): 5194
#
# Profit (in millions): 580.3
#
#
#
# Year: 1999
#
# Rank: 312
#
# Company: Ryder System
#
# Revenue (in millions): 5188.7
#
# Profit (in millions): 159.1
#
#
#
# Year: 1999
#
# Rank: 313
#
# Company: AirTouch Communications
#
# Revenue (in millions): 5181
#
# Profit (in millions): 725
#
#
#
# Year: 1999
#
# Rank: 314
#
# Company: CMS Energy
#
# Revenue (in millions): 5141
#
# Profit (in millions): 285
#
#
#
# Year: 1999
#
# Rank: 315
#
# Company: Gannett
#
# Revenue (in millions): 5121.3
#
# Profit (in millions): 999.9
#
#
#
# Year: 1999
#
# Rank: 316
#
# Company: First Data
#
# Revenue (in millions): 5117.6
#
# Profit (in millions): 465.7
#
#
#
# Year: 1999
#
# Rank: 317
#
# Company: Cooper Industries
#
# Revenue (in millions): 5100.6
#
# Profit (in millions): 423
#
#
#
# Year: 1999
#
# Rank: 318
#
# Company: Nordstrom
#
# Revenue (in millions): 5027.9
#
# Profit (in millions): 206.7
#
#
#
# Year: 1999
#
# Rank: 319
#
# Company: Owens Corning
#
# Revenue (in millions): 5009
#
# Profit (in millions): -705
#
#
#
# Year: 1999
#
# Rank: 320
#
# Company: General Dynamics
#
# Revenue (in millions): 4970
#
# Profit (in millions): 364
#
#
#
# Year: 1999
#
# Rank: 321
#
# Company: CNF
#
# Revenue (in millions): 4941.5
#
# Profit (in millions): 139
#
#
#
# Year: 1999
#
# Rank: 322
#
# Company: Sherwin-Williams
#
# Revenue (in millions): 4934.4
#
# Profit (in millions): 272.9
#
#
#
# Year: 1999
#
# Rank: 323
#
# Company: Air Products & Chem.
#
# Revenue (in millions): 4933.8
#
# Profit (in millions): 546.8
#
#
#
# Year: 1999
#
# Rank: 324
#
# Company: Dover
#
# Revenue (in millions): 4876.7
#
# Profit (in millions): 378.8
#
#
#
# Year: 1999
#
# Rank: 325
#
# Company: Quaker Oats
#
# Revenue (in millions): 4842.5
#
# Profit (in millions): 284.5
#
#
#
# Year: 1999
#
# Rank: 326
#
# Company: Praxair
#
# Revenue (in millions): 4833
#
# Profit (in millions): 425
#
#
#
# Year: 1999
#
# Rank: 327
#
# Company: Starwood Hotels & Rsrts.
#
# Revenue (in millions): 4832
#
# Profit (in millions): 1255
#
#
#
# Year: 1999
#
# Rank: 328
#
# Company: Automatic Data Proc.
#
# Revenue (in millions): 4798.1
#
# Profit (in millions): 605.3
#
#
#
# Year: 1999
#
# Rank: 329
#
# Company: Fortune Brands
#
# Revenue (in millions): 4797.2
#
# Profit (in millions): 263.1
#
#
#
# Year: 1999
#
# Rank: 330
#
# Company: RadioShack
#
# Revenue (in millions): 4787.9
#
# Profit (in millions): 61.3
#
#
#
# Year: 1999
#
# Rank: 331
#
# Company: Mattel
#
# Revenue (in millions): 4781.9
#
# Profit (in millions): 332.3
#
#
#
# Year: 1999
#
# Rank: 332
#
# Company: Browning-Ferris Industries
#
# Revenue (in millions): 4745.7
#
# Profit (in millions): 338.8
#
#
#
# Year: 1999
#
# Rank: 333
#
# Company: ServiceMaster
#
# Revenue (in millions): 4724.1
#
# Profit (in millions): 190
#
#
#
# Year: 1999
#
# Rank: 334
#
# Company: Oxford Health Plans
#
# Revenue (in millions):
#
# Profit (in millions): -624.5
#
#
#
# Year: 1999
#
# Rank: 335
#
# Company: Computer Assoc. Intl.
#
# Revenue (in millions): 4719
#
# Profit (in millions): 1169
#
#
#
# Year: 1999
#
# Rank: 336
#
# Company: Parker Hannifin
#
# Revenue (in millions): 4633
#
# Profit (in millions): 319.6
#
#
#
# Year: 1999
#
# Rank: 337
#
# Company: Unum
#
# Revenue (in millions): 4630.8
#
# Profit (in millions): 363.4
#
#
#
# Year: 1999
#
# Rank: 338
#
# Company: Olsten
#
# Revenue (in millions): 4602.8
#
# Profit (in millions): 4.4
#
#
#
# Year: 1999
#
# Rank: 339
#
# Company: Foster Wheeler
#
# Revenue (in millions): 4597
#
# Profit (in millions): -31.5
#
#
#
# Year: 1999
#
# Rank: 340
#
# Company: Mead
#
# Revenue (in millions): 4579.2
#
# Profit (in millions): 119.7
#
#
#
# Year: 1999
#
# Rank: 341
#
# Company: Allegiance
#
# Revenue (in millions): 4574.4
#
# Profit (in millions): 126.4
#
#
#
# Year: 1999
#
# Rank: 342
#
# Company: Black & Decker
#
# Revenue (in millions): 4559.9
#
# Profit (in millions): -754.8
#
#
#
# Year: 1999
#
# Rank: 343
#
# Company: Merisel
#
# Revenue (in millions): 4553
#
# Profit (in millions): 18.5
#
#
#
# Year: 1999
#
# Rank: 344
#
# Company: Union Camp
#
# Revenue (in millions): 4502.9
#
# Profit (in millions): 19.3
#
#
#
# Year: 1999
#
# Rank: 345
#
# Company: Eastman Chemical
#
# Revenue (in millions): 4481
#
# Profit (in millions): 249
#
#
#
# Year: 1999
#
# Rank: 346
#
# Company: Bethlehem Steel
#
# Revenue (in millions): 4477.8
#
# Profit (in millions): 120.1
#
#
#
# Year: 1999
#
# Rank: 347
#
# Company: Science Applications Intl.
#
# Revenue (in millions): 4476.8
#
# Profit (in millions): 147.6
#
#
#
# Year: 1999
#
# Rank: 348
#
# Company: Corporate Express
#
# Revenue (in millions): 4474.6
#
# ...
#
# Revenue (in millions): 2,155.60
#
# Profit (in millions): 97.1
#
#
#
# Year: 2009
#
# Rank: 860
#
# Company: Imation
#
# Revenue (in millions): 2,154.60
#
# Profit (in millions): -33.3
#
#
#
# Year: 2009
#
# Rank: 861
#
# Company: Select Medical Holdings
#
# Revenue (in millions): 2,153.40
#
# Profit (in millions): 22.4
#
#
#
# Year: 2009
#
# Rank: 862
#
# Company: Briggs & Stratton
#
# Revenue (in millions): 2,151.40
#
# Profit (in millions): 22.6
#
#
#
# Year: 2009
#
# Rank: 863
#
# Company: Phoenix
#
# Revenue (in millions): 2,150.90
#
# Profit (in millions): -726
#
#
#
# Year: 2009
#
# Rank: 864
#
# Company: Atlas America
#
# Revenue (in millions): 2,149.90
#
# Profit (in millions): -6.2
#
#
#
# Year: 2009
#
# Rank: 865
#
# Company: Equity Residential
#
# Revenue (in millions): 2,148.90
#
# Profit (in millions): 420.1
#
#
#
# Year: 2009
#
# Rank: 866
#
# Company: Helix Energy Solutions Group
#
# Revenue (in millions): 2,148.30
#
# Profit (in millions): -630.8
#
#
#
# Year: 2009
#
# Rank: 867
#
# Company: Southwest Gas
#
# Revenue (in millions): 2,144.70
#
# Profit (in millions): 61
#
#
#
# Year: 2009
#
# Rank: 868
#
# Company: DynCorp International
#
# Revenue (in millions): 2,139.80
#
# Profit (in millions): 48
#
#
#
# Year: 2009
#
# Rank: 869
#
# Company: Acuity Brands
#
# Revenue (in millions): 2,124.40
#
# Profit (in millions): 148.3
#
#
#
# Year: 2009
#
# Rank: 870
#
# Company: Martin Marietta Materials
#
# Revenue (in millions): 2,124.00
#
# Profit (in millions): 176.3
#
#
#
# Year: 2009
#
# Rank: 871
#
# Company: T. Rowe Price
#
# Revenue (in millions): 2,121.30
#
# Profit (in millions): 490.8
#
#
#
# Year: 2009
#
# Rank: 872
#
# Company: Iasis Healthcare
#
# Revenue (in millions): 2,115.50
#
# Profit (in millions): 36.3
#
#
#
# Year: 2009
#
# Rank: 873
#
# Company: BE Aerospace
#
# Revenue (in millions): 2,110.00
#
# Profit (in millions): -99.4
#
#
#
# Year: 2009
#
# Rank: 874
#
# Company: American Axle & Manufacturing
#
# Revenue (in millions): 2,109.20
#
# Profit (in millions): -1,224.30
#
#
#
# Year: 2009
#
# Rank: 875
#
# Company: Warnaco Group
#
# Revenue (in millions): 2,107.60
#
# Profit (in millions): 47.3
#
#
#
# Year: 2009
#
# Rank: 876
#
# Company: Varian Medical Systems
#
# Revenue (in millions): 2,104.90
#
# Profit (in millions): 279.5
#
#
#
# Year: 2009
#
# Rank: 877
#
# Company: Cenveo
#
# Revenue (in millions): 2,098.70
#
# Profit (in millions): -298
#
#
#
# Year: 2009
#
# Rank: 878
#
# Company: Guess
#
# Revenue (in millions): 2,093.40
#
# Profit (in millions): 213.6
#
#
#
# Year: 2009
#
# Rank: 879
#
# Company: Sauer-Danfoss
#
# Revenue (in millions): 2,090.50
#
# Profit (in millions): -29.1
#
#
#
# Year: 2009
#
# Rank: 880
#
# Company: Applied Industrial Technologies
#
# Revenue (in millions): 2,089.50
#
# Profit (in millions): 95.5
#
#
#
# Year: 2009
#
# Rank: 881
#
# Company: Piedmont Natural Gas
#
# Revenue (in millions): 2,089.10
#
# Profit (in millions): 110
#
#
#
# Year: 2009
#
# Rank: 882
#
# Company: Pacer International
#
# Revenue (in millions): 2,087.70
#
# Profit (in millions): -16.6
#
#
#
# Year: 2009
#
# Rank: 883
#
# Company: Beazer Homes USA
#
# Revenue (in millions): 2,078.10
#
# Profit (in millions): -951.9
#
#
#
# Year: 2009
#
# Rank: 884
#
# Company: AptarGroup
#
# Revenue (in millions): 2,071.70
#
# Profit (in millions): 153.5
#
#
#
# Year: 2009
#
# Rank: 885
#
# Company: Paychex
#
# Revenue (in millions): 2,066.30
#
# Profit (in millions): 576.1
#
#
#
# Year: 2009
#
# Rank: 886
#
# Company: ON Semiconductor
#
# Revenue (in millions): 2,054.80
#
# Profit (in millions): -380.1
#
#
#
# Year: 2009
#
# Rank: 887
#
# Company: Maxim Integrated Products
#
# Revenue (in millions): 2,052.80
#
# Profit (in millions): 317.7
#
#
#
# Year: 2009
#
# Rank: 888
#
# Company: Univision Communications
#
# Revenue (in millions): 2,049.80
#
# Profit (in millions): -5,127.30
#
#
#
# Year: 2009
#
# Rank: 889
#
# Company: Amerco
#
# Revenue (in millions): 2,049.20
#
# Profit (in millions): 67.8
#
#
#
# Year: 2009
#
# Rank: 890
#
# Company: Carpenter Technology
#
# Revenue (in millions): 2,042.40
#
# Profit (in millions): 277.7
#
#
#
# Year: 2009
#
# Rank: 891
#
# Company: Helmerich & Payne
#
# Revenue (in millions): 2,036.50
#
# Profit (in millions): 461.7
#
#
#
# Year: 2009
#
# Rank: 892
#
# Company: Alexander & Baldwin
#
# Revenue (in millions): 2,031.00
#
# Profit (in millions): 132
#
#
#
# Year: 2009
#
# Rank: 893
#
# Company: Enersys
#
# Revenue (in millions): 2,026.60
#
# Profit (in millions): 59.7
#
#
#
# Year: 2009
#
# Rank: 894
#
# Company: PerkinElmer
#
# Revenue (in millions): 2,022.90
#
# Profit (in millions): 126.4
#
#
#
# Year: 2009
#
# Rank: 895
#
# Company: Alliance One International
#
# Revenue (in millions): 2,018.50
#
# Profit (in millions): 16.9
#
#
#
# Year: 2009
#
# Rank: 896
#
# Company: Gardner Denver
#
# Revenue (in millions): 2,018.30
#
# Profit (in millions): 166
#
#
#
# Year: 2009
#
# Rank: 897
#
# Company: Herman Miller
#
# Revenue (in millions): 2,012.10
#
# Profit (in millions): 152.3
#
#
#
# Year: 2009
#
# Rank: 898
#
# Company: Belden
#
# Revenue (in millions): 2,005.90
#
# Profit (in millions): -361
#
#
#
# Year: 2009
#
# Rank: 899
#
# Company: MEMC Electronic Materials
#
# Revenue (in millions): 2,004.50
#
# Profit (in millions): 387.4
#
#
#
# Year: 2009
#
# Rank: 900
#
# Company: A. Schulman
#
# Revenue (in millions): 1,984.00
#
# Profit (in millions): 18
#
#
#
# Year: 2009
#
# Rank: 901
#
# Company: Oceaneering International
#
# Revenue (in millions): 1,977.40
#
# Profit (in millions): 199.4
#
#
#
# Year: 2009
#
# Rank: 902
#
# Company: Ryland Group
#
# Revenue (in millions): 1,976.10
#
# Profit (in millions): -396.6
#
#
#
# Year: 2009
#
# Rank: 903
#
# Company: Cephalon
#
# Revenue (in millions): 1,974.60
#
# Profit (in millions): 222.5
#
#
#
# Year: 2009
#
# Rank: 904
#
# Company: Mettler-Toledo International
#
# Revenue (in millions): 1,973.30
#
# Profit (in millions): 202.8
#
#
#
# Year: 2009
#
# Rank: 905
#
# Company: Men's Wearhouse
#
# Revenue (in millions): 1,972.40
#
# Profit (in millions): 58.8
#
#
#
# Year: 2009
#
# Rank: 906
#
# Company: Key Energy Services
#
# Revenue (in millions): 1,972.10
#
# Profit (in millions): 84.1
#
#
#
# Year: 2009
#
# Rank: 907
#
# Company: Century Aluminum
#
# Revenue (in millions): 1,970.80
#
# Profit (in millions): -898.3
#
#
#
# Year: 2009
#
# Rank: 908
#
# Company: Cimarex Energy
#
# Revenue (in millions): 1,970.30
#
# Profit (in millions): -901.7
#
#
#
# Year: 2009
#
# Rank: 909
#
# Company: Leap Wireless International
#
# Revenue (in millions): 1,958.90
#
# Profit (in millions): -147.8
#
#
#
# Year: 2009
#
# Rank: 910
#
# Company: Baldor Electric
#
# Revenue (in millions): 1,954.70
#
# Profit (in millions): 99.4
#
#
#
# Year: 2009
#
# Rank: 911
#
# Company: Polaris Industries
#
# Revenue (in millions): 1,948.30
#
# Profit (in millions): 117.4
#
#
#
# Year: 2009
#
# Rank: 912
#
# Company: PharMerica
#
# Revenue (in millions): 1,947.30
#
# Profit (in millions): 5
#
#
#
# Year: 2009
#
# Rank: 913
#
# Company: Total System Services
#
# Revenue (in millions): 1,938.60
#
# Profit (in millions): 250.1
#
#
#
# Year: 2009
#
# Rank: 914
#
# Company: LKQ
#
# Revenue (in millions): 1,937.30
#
# Profit (in millions): 99.9
#
#
#
# Year: 2009
#
# Rank: 915
#
# Company: Equifax
#
# Revenue (in millions): 1,935.70
#
# Profit (in millions): 272.8
#
#
#
# Year: 2009
#
# Rank: 916
#
# Company: Brookdale Senior Living
#
# Revenue (in millions): 1,928.10
#
# Profit (in millions): -373.2
#
#
#
# Year: 2009
#
# Rank: 917
#
# Company: Pep Boys
#
# Revenue (in millions): 1,927.80
#
# Profit (in millions): -30.4
#
#
#
# Year: 2009
#
# Rank: 918
#
# Company: Itron
#
# Revenue (in millions): 1,909.60
#
# Profit (in millions): 28.1
#
#
#
# Year: 2009
#
# Rank: 919
#
# Company: Valmont Industries
#
# Revenue (in millions): 1,907.30
#
# Profit (in millions): 132.4
#
#
#
# Year: 2009
#
# Rank: 920
#
# Company: M&F Worldwide
#
# Revenue (in millions): 1,906.20
#
# Profit (in millions): 67.7
#
#
#
# Year: 2009
#
# Rank: 921
#
# Company: Moog
#
# Revenue (in millions): 1,902.70
#
# Profit (in millions): 119.1
#
#
#
# Year: 2009
#
# Rank: 922
#
# Company: Jo-Ann Stores
#
# Revenue (in millions): 1,901.10
#
# Profit (in millions): 21.9
#
#
#
# Year: 2009
#
# Rank: 923
#
# Company: McClatchy
#
# Revenue (in millions): 1,900.50
#
# Profit (in millions): -4
#
#
#
# Year: 2009
#
# Rank: 924
#
# Company: Markel
#
# Revenue (in millions): 1,898.30
#
# Profit (in millions): -58.8
#
#
#
# Year: 2009
#
# Rank: 925
#
# Company: Complete Production Services
#
# Revenue (in millions): 1,898.10
#
# Profit (in millions): -85.5
#
#
#
# Year: 2009
#
# Rank: 926
#
# Company: Buckeye GP Holdings
#
# Revenue (in millions): 1,896.70
#
# Profit (in millions): 26.5
#
#
#
# Year: 2009
#
# Rank: 927
#
# Company: Teledyne Technologies
#
# Revenue (in millions): 1,893.00
#
# Profit (in millions): 111.3
#
#
#
# Year: 2009
#
# Rank: 928
#
# Company: National Semiconductor
#
# Revenue (in millions): 1,885.90
#
# Profit (in millions): 332.3
#
#
#
# Year: 2009
#
# Rank: 929
#
# Company: A?ropostale
#
# Revenue (in millions): 1,885.50
#
# Profit (in millions): 149.4
#
#
#
# Year: 2009
#
# Rank: 930
#
# Company: Retail Ventures
#
# Revenue (in millions): 1,885.00
#
# Profit (in millions): -68.9
#
#
#
# Year: 2009
#
# Rank: 931
#
# Company: Priceline.com
#
# Revenue (in millions): 1,884.80
#
# Profit (in millions): 193.5
#
#
#
# Year: 2009
#
# Rank: 932
#
# Company: Sun Healthcare Group
#
# Revenue (in millions): 1,883.70
#
# Profit (in millions): 109.3
#
#
#
# Year: 2009
#
# Rank: 933
#
# Company: Superior Energy Services
#
# Revenue (in millions): 1,881.10
#
# Profit (in millions): 361.7
#
#
#
# Year: 2009
#
# Rank: 934
#
# Company: Sentry Insurance Group
#
# Revenue (in millions): 1,879.60
#
# Profit (in millions): 78.1
#
#
#
# Year: 2009
#
# Rank: 935
#
# Company: Inergy Holdings
#
# Revenue (in millions): 1,878.90
#
# Profit (in millions): 35.5
#
#
#
# Year: 2009
#
# Rank: 936
#
# Company: Toro
#
# Revenue (in millions): 1,878.20
#
# Profit (in millions): 119.7
#
#
#
# Year: 2009
#
# Rank: 937
#
# Company: IDT
#
# Revenue (in millions): 1,878.00
#
# Profit (in millions): -224.3
#
#
#
# Year: 2009
#
# Rank: 938
#
# Company: Kinetic Concepts
#
# Revenue (in millions): 1,877.90
#
# Profit (in millions): 173.9
#
#
#
# Year: 2009
#
# Rank: 939
#
# Company: Modine Manufacturing
#
# Revenue (in millions): 1,877.80
#
# Profit (in millions): -65.6
#
#
#
# Year: 2009
#
# Rank: 940
#
# Company: HealthSouth
#
# Revenue (in millions): 1,871.20
#
# Profit (in millions): 252.4
#
#
#
# Year: 2009
#
# Rank: 941
#
# Company: ManTech International
#
# Revenue (in millions): 1,870.90
#
# Profit (in millions): 90.3
#
#
#
# Year: 2009
#
# Rank: 942
#
# Company: Hill-Rom Holdings
#
# Revenue (in millions): 1,862.00
#
# Profit (in millions): 115.8
#
#
#
# Year: 2009
#
# Rank: 943
#
# Company: Lender Processing Services
#
# Revenue (in millions): 1,861.90
#
# Profit (in millions): 230.9
#
#
#
# Year: 2009
#
# Rank: 944
#
# Company: Hub Group
#
# Revenue (in millions): 1,860.60
#
# Profit (in millions): 59.2
#
#
#
# Year: 2009
#
# Rank: 945
#
# Company: Mueller Water Products
#
# Revenue (in millions): 1,859.30
#
# Profit (in millions): 42
#
#
#
# Year: 2009
#
# Rank: 946
#
# Company: PSS World Medical
#
# Revenue (in millions): 1,855.80
#
# Profit (in millions): 56.8
#
#
#
# Year: 2009
#
# Rank: 947
#
# Company: RBS Global
#
# Revenue (in millions): 1,853.50
#
# Profit (in millions): 40.9
#
#
#
# Year: 2009
#
# Rank: 948
#
# Company: Kansas City Southern
#
# Revenue (in millions): 1,852.10
#
# Profit (in millions): 183.9
#
#
#
# Year: 2009
#
# Rank: 949
#
# Company: Solo Cup
#
# Revenue (in millions): 1,847.00
#
# Profit (in millions): -12.1
#
#
#
# Year: 2009
#
# Rank: 950
#
# Company: Plexus
#
# Revenue (in millions): 1,841.60
#
# Profit (in millions): 84.1
#
#
#
# Year: 2009
#
# Rank: 951
#
# Company: Xilinx
#
# Revenue (in millions): 1,841.40
#
# Profit (in millions): 374
#
#
#
# Year: 2009
#
# Rank: 952
#
# Company: Westar Energy
#
# Revenue (in millions): 1,839.00
#
# Profit (in millions): 178.1
#
#
#
# Year: 2009
#
# Rank: 953
#
# Company: Urban Outfitters
#
# Revenue (in millions): 1,834.60
#
# Profit (in millions): 199.4
#
#
#
# Year: 2009
#
# Rank: 954
#
# Company: Arkansas Best
#
# Revenue (in millions): 1,833.10
#
# Profit (in millions): 29.2
#
#
#
# Year: 2009
#
# Rank: 955
#
# Company: Curtiss-Wright
#
# Revenue (in millions): 1,830.10
#
# Profit (in millions): 109.4
#
#
#
# Year: 2009
#
# Rank: 956
#
# Company: Covance
#
# Revenue (in millions): 1,827.10
#
# Profit (in millions): 196.8
#
#
#
# Year: 2009
#
# Rank: 957
#
# Company: Wendy's/Arby's Group
#
# Revenue (in millions): 1,822.80
#
# Profit (in millions): -479.7
#
#
#
# Year: 2009
#
# Rank: 958
#
# Company: Perrigo
#
# Revenue (in millions): 1,822.10
#
# Profit (in millions): 135.8
#
#
#
# Year: 2009
#
# Rank: 959
#
# Company: Radian Group
#
# Revenue (in millions): 1,808.00
#
# Profit (in millions): -410.6
#
#
#
# Year: 2009
#
# Rank: 960
#
# Company: E.W. Scripps
#
# Revenue (in millions): 1,806.20
#
# Profit (in millions): -476.6
#
#
#
# Year: 2009
#
# Rank: 961
#
# Company: Michael Foods
#
# Revenue (in millions): 1,804.40
#
# Profit (in millions): 46.9
#
#
#
# Year: 2009
#
# Rank: 962
#
# Company: Cypress Semiconductor
#
# Revenue (in millions): 1,803.00
#
# Profit (in millions): -430.3
#
#
#
# Year: 2009
#
# Rank: 963
#
# Company: Fred's
#
# Revenue (in millions): 1,798.80
#
# Profit (in millions): 16.6
#
#
#
# Year: 2009
#
# Rank: 964
#
# Company: Vought Aircraft Industries
#
# Revenue (in millions): 1,796.60
#
# Profit (in millions): 93.7
#
#
#
# Year: 2009
#
# Rank: 965
#
# Company: Beacon Roofing Supply
#
# Revenue (in millions): 1,784.50
#
# Profit (in millions): 40.3
#
#
#
# Year: 2009
#
# Rank: 966
#
# Company: Pool
#
# Revenue (in millions): 1,783.70
#
# Profit (in millions): 57
#
#
#
# Year: 2009
#
# Rank: 967
#
# Company: Boyd Gaming
#
# Revenue (in millions): 1,781.00
#
# Profit (in millions): -223
#
#
#
# Year: 2009
#
# Rank: 968
#
# Company: Psychiatric Solutions
#
# Revenue (in millions): 1,780.80
#
# Profit (in millions): 105
#
#
#
# Year: 2009
#
# Rank: 969
#
# Company: MSC Industrial Direct
#
# Revenue (in millions): 1,779.80
#
# Profit (in millions): 196.2
#
#
#
# Year: 2009
#
# Rank: 970
#
# Company: American Greetings
#
# Revenue (in millions): 1,776.80
#
# Profit (in millions): 83
#
#
#
# Year: 2009
#
# Rank: 971
#
# Company: Duane Reade Holdings
#
# Revenue (in millions): 1,774.00
#
# Profit (in millions): -72.8
#
#
#
# Year: 2009
#
# Rank: 972
#
# Company: Mutual of America Life
#
# Revenue (in millions): 1,772.90
#
# Profit (in millions): -53.5
#
#
#
# Year: 2009
#
# Rank: 973
#
# Company: KAR Holdings
#
# Revenue (in millions): 1,771.40
#
# Profit (in millions): -216.2
#
#
#
# Year: 2009
#
# Rank: 974
#
# Company: Verso Paper
#
# Revenue (in millions): 1,766.80
#
# Profit (in millions): -62.8
#
#
#
# Year: 2009
#
# Rank: 975
#
# Company: RSC Holdings
#
# Revenue (in millions): 1,765.20
#
# Profit (in millions): 122.5
#
#
#
# Year: 2009
#
# Rank: 976
#
# Company: Olin
#
# Revenue (in millions): 1,764.50
#
# Profit (in millions): 157.7
#
#
#
# Year: 2009
#
# Rank: 977
#
# Company: Bio-Rad Laboratories
#
# Revenue (in millions): 1,764.40
#
# Profit (in millions): 89.5
#
#
#
# Year: 2009
#
# Rank: 978
#
# Company: NCI Building Systems
#
# Revenue (in millions): 1,764.20
#
# Profit (in millions): 78.9
#
#
#
# Year: 2009
#
# Rank: 979
#
# Company: Teradata
#
# Revenue (in millions): 1,762.00
#
# Profit (in millions): 250
#
#
#
# Year: 2009
#
# Rank: 980
#
# Company: Watson Wyatt Worldwide
#
# Revenue (in millions): 1,760.10
#
# Profit (in millions): 155.4
#
#
#
# Year: 2009
#
# Rank: 981
#
# Company: Children's Place Retail Stores
#
# Revenue (in millions): 1,759.50
#
# Profit (in millions): 82.4
#
#
#
# Year: 2009
#
# Rank: 982
#
# Company: Furniture Brands International
#
# Revenue (in millions): 1,758.50
#
# Profit (in millions): -385.9
#
#
#
# Year: 2009
#
# Rank: 983
#
# Company: Invacare
#
# Revenue (in millions): 1,755.70
#
# Profit (in millions): 38.6
#
#
#
# Year: 2009
#
# Rank: 984
#
# Company: Moody's
#
# Revenue (in millions): 1,755.40
#
# Profit (in millions): 457.6
#
#
#
# Year: 2009
#
# Rank: 985
#
# Company: PC Connection
#
# Revenue (in millions): 1,753.70
#
# Profit (in millions): 10.4
#
#
#
# Year: 2009
#
# Rank: 986
#
# Company: Public Storage
#
# Revenue (in millions): 1,745.60
#
# Profit (in millions): 935.2
#
#
#
# Year: 2009
#
# Rank: 987
#
# Company: Portland General Electric
#
# Revenue (in millions): 1,745.00
#
# Profit (in millions): 87
#
#
#
# Year: 2009
#
# Rank: 988
#
# Company: Eagle Rock Energy Partners
#
# Revenue (in millions): 1,743.30
#
# Profit (in millions): 87.5
#
#
#
# Year: 2009
#
# Rank: 989
#
# Company: Cinemark Holdings
#
# Revenue (in millions): 1,742.30
#
# Profit (in millions): -48.3
#
#
#
# Year: 2009
#
# Rank: 990
#
# Company: Sunrise Senior Living
#
# Revenue (in millions): 1,741.40
#
# Profit (in millions): -439.2
#
#
#
# Year: 2009
#
# Rank: 991
#
# Company: Bob Evans Farms
#
# Revenue (in millions): 1,737.00
#
# Profit (in millions): 64.9
#
#
#
# Year: 2009
#
# Rank: 992
#
# Company: OM Group
#
# Revenue (in millions): 1,736.80
#
# Profit (in millions): 135
#
#
#
# Year: 2009
#
# Rank: 993
#
# Company: Fleetwood Enterprises
#
# Revenue (in millions): 1,736.60
#
# Profit (in millions): -1
#
#
#
# Year: 2009
#
# Rank: 994
#
# Company: BMC Software
#
# Revenue (in millions): 1,731.60
#
# Profit (in millions): 313.6
#
#
#
# Year: 2009
#
# Rank: 995
#
# Company: Dun & Bradstreet
#
# Revenue (in millions): 1,730.40
#
# Profit (in millions): 310.6
#
#
#
# Year: 2009
#
# Rank: 996
#
# Company: Tellabs
#
# Revenue (in millions): 1,729.00
#
# Profit (in millions): -930.1
#
#
#
# Year: 2009
#
# Rank: 997
#
# Company: Administaff
#
# Revenue (in millions): 1,724.40
#
# Profit (in millions): 45.8
#
#
#
# Year: 2009
#
# Rank: 998
#
# Company: Sanderson Farms
#
# Revenue (in millions): 1,723.60
#
# Profit (in millions): -43.1
#
#
#
# Year: 2009
#
# Rank: 999
#
# Company: MGIC Investment
#
# Revenue (in millions): 1,721.50
#
# Profit (in millions): -518.9
#
#
#
# Year: 2009
#
# Rank: 1000
#
# Company: Career Education
#
# Revenue (in millions): 1,720.80
#
# Profit (in millions): 60.1

# %%
# # Convert the list of dictionaries into a DataFrame
df = pd.DataFrame(result)
# # Display the DataFrame
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## 3.2 Handle damaged txt data

# %%
import pandas as pd

# %%
"""Your turn -- Class practice"""
file_path = 'damaged_data.txt'  # use your file path

# Define the expected keys
expected_keys = ["Region", "State", "Attraction", "Description", 
                 "Food Specialty", "Food Description", 
                 "Best Time to Visit", "Notable Events"]


# Function to process a block of text and return a dictionary
def process_block(block):
    entity = {key: None for key in expected_keys}
    #Your code:
    
    return entity

# Read and process the file
current_data= []
result= []
with open(file_path,'r') as file:
    for line in file:
        # Your code:

# Convert the list of dictionaries into a DataFrame
dfnew = pd.DataFrame(result)

# Display the DataFrame
dfnew
# Out:
#   Cell In[35], line 25
#     dfnew = pd.DataFrame(result)
#                                 ^
# IndentationError: expected an indented block after 'for' statement on line 21

# %% [markdown]
# ### Practice 🧪 Lab: Cleaning “Damaged” Data with pandas
#
# In this practice, you’ll practice detecting and fixing common data problems:
#
# - Rows with **missing fields**
# - Rows with **extra fields** (e.g., too many columns due to extra commas)
# - **Wrong types** (strings in numeric columns)
# - **Out-of-range values** (e.g., impossible GPA)
# - Empty strings vs true missing values (`NaN`)
#
# You will:
# 1) Load a deliberately “damaged” CSV,
# 2) Identify & filter bad rows,
# 3) Coerce types, and
# 4) Produce a clean DataFrame ready for analysis.

# %%
# 🚧 Create a deliberately “damaged” CSV (run this cell once)
source_csv = """Student_ID,Name,Major,Credits,GPA,Grad_Year
1001,Alice,Computer Science,120,3.85,2026
1002,Bob,Math, ,3.10,2025
1003,Charlie,Physics,98,3O,2024
1004,Diana,Economics,140,4.7,2023
1005,Ed,Computer Science,129,N/A,2027
1006, ,Biology,88,2.95,2028
1007,Grace,Physics,101,3.40,2029,EXTRA_TOKEN
,Henry,Math,64,2.70,2026
1009,Ivy,,110,3.20,2025
1010,Jack,Economics,215,3.50,2035
1011,Kate,Chemistry,95,3.00,
1012,Liam,Computer Science,NaN,3.60,2024
1013,Mia,Math,77,,2025
1014,Noah,Physics,85,3.25,2027
1015,Olivia,Economics,,2.80,2026
"""

with open("damaged_students.csv", "w") as f:
    f.write(source_csv)

# %%
# Import library
import pandas as pd

# Load the csv 
# skips rows with too many columns
df = pd.read_csv("damaged_students.csv", on_bad_lines="skip") 
df

# Inspect 
df.info()
df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student_ID  13 non-null     float64
#  1   Name        14 non-null     object
#  2   Major       13 non-null     object
#  3   Credits     12 non-null     object
#  4   GPA         12 non-null     object
#  5   Grad_Year   13 non-null     float64
# dtypes: float64(2), object(4)
# memory usage: 804.0+ bytes
#    Student_ID     Name             Major Credits   GPA  Grad_Year
# 0      1001.0    Alice  Computer Science     120  3.85     2026.0
# 1      1002.0      Bob              Math          3.10     2025.0
# 2      1003.0  Charlie           Physics      98    3O     2024.0
# 3      1004.0    Diana         Economics     140   4.7     2023.0
# 4      1005.0       Ed  Computer Science     129   NaN     2027.0
# 5      1006.0                    Biology      88  2.95     2028.0
# 6         NaN    Henry              Math      64  2.70     2026.0
# 7      1009.0      Ivy               NaN     110  3.20     2025.0
# 8      1010.0     Jack         Economics     215  3.50     2035.0
# 9      1011.0     Kate         Chemistry      95  3.00        NaN

# %%
# Clean the data

# Handle missing or bad rows
df = df.dropna(subset=["Student_ID", "Name", "Major", "Credits", "GPA", "Grad_Year"])

# %%
# Convert data types
df["Credits"] = pd.to_numeric(df["Credits"], errors="coerce")
df["GPA"] = pd.to_numeric(df["GPA"], errors="coerce")
df["Grad_Year"] = pd.to_numeric(df["Grad_Year"], errors="coerce")

# %%
# Remove impossible values
df = df[(df["GPA"] >= 0) & (df["GPA"] <= 4)]
df = df[(df["Credits"] >= 0) & (df["Credits"] <= 200)]

# %%
# View the cleaned DataSet
print("Before cleaning", len(pd.read_csv("damaged_students.csv", on_bad_lines="skip")))
print("After cleaning:", len(df))
df
# Out:
# Before cleaning 14
# After cleaning: 3
#     Student_ID   Name             Major  Credits   GPA  Grad_Year
# 0       1001.0  Alice  Computer Science    120.0  3.85     2026.0
# 5       1006.0                  Biology     88.0  2.95     2028.0
# 12      1014.0   Noah           Physics     85.0  3.25     2027.0
